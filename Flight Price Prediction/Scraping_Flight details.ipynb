# %% [markdown]
# ## FLIGHT PRICE PREDICTION
# Anyone who has booked a flight ticket knows how unexpectedly the prices vary. The cheapest available ticket on a given flight gets more and less expensive over time. This usually happens as an attempt to maximize revenue based on -
#
# Time of purchase patterns (making sure last-minute purchases are expensive)
# Keeping the flight as full as they want it (raising prices on a flight which is filling up in order to reduce sales and hold back inventory for those expensive last-minute expensive purchases) So, you have to work on a project where you collect data of flight fares with other features and work to make a model to predict fares of flights.
# ## STEPS
# ## 1. Data Collection
# You have to scrape at least 1500 rows of data. You can scrape more data as well, it’s up to you, More the data better the model In this section you have to scrape the data of flights from different websites (yatra.com, skyscanner.com, official websites of airlines, etc). The number of columns for data doesn’t have limit, it’s up to you and your creativity. Generally, these columns areairline name, date of journey, source, destination, route, departure time, arrival time, duration, total stops and the target variable price. You can make changes to it, you can add or you can remove some columns, it completely depends on the website from which you are fetching the data.
#
# ##### COLUMNS:
# ##### airline name, date of journey, source, destination, route, departure time, arrival time, duration, total stops and the target variable price

# %%
import pandas as pd
import selenium
from selenium import webdriver
import time
from time import sleep

import warnings
warnings.filterwarnings('ignore')

# %%
Airline_name = []
Date = []
arrival_time=[]
dep_time = []
source = []
destination=[]
duration = []
total_stops = []
price=[]

# %%
#loading web driver for June 9 Mumbai to Delhi
driver = webdriver.Chrome('chromedriver.exe') 
driver.get('https://flight.yatra.com/air-search-ui/dom2/trigger?type=O&viewName=normal&flexi=0&noOfSegments=1&origin=BOM&originCountry=IN&destination=DEL&destinationCountry=IN&flight_depart_date=09%2F06%2F2022&ADT=1&CHD=0&INF=0&class=Economy&source=fresco-home&unqvaldesktop=288596651391')
driver.maximize_window()

# %%
last_height = driver.execute_script("return document.documentElement.scrollHeight")

# %%
while True:
    # Scroll down 'till "next load".
    driver.execute_script("window.scrollTo(0, document.documentElement.scrollHeight);")

    # Wait to load everything thus far.
    time.sleep(2)

    # Calculate new scroll height and compare with last scroll height.
    new_height = driver.execute_script("return document.documentElement.scrollHeight")
    if new_height == last_height:
        break
    last_height = new_height

    # One last scroll just in case.
driver.execute_script("window.scrollTo(0, document.documentElement.scrollHeight);")
sleep(2)

# %%
#airline tags
try:
    #tag = driver.find_elements_by_xpath('//div/div[1]/div[1]/div/div[2]/span')
    tag = driver.find_elements_by_xpath('//span[@class="i-b text ellipsis"]')
    for i in tag:
        Airline_name.append(i.text)
        
    l1 = len(Airline_name)
    length=l1
except:
    Airline_name.append('Nan')

#Airline_name
#len(Airline_name)


#departure time
try:
    tag = driver.find_elements_by_xpath('//div[@class="i-b pr"]')
    for i in tag:
        dep_time.append(i.text)
except:
    dep_time.append('Nan')


#arrival time
try:
    tag = driver.find_elements_by_xpath('//p[@class="bold fs-15 mb-2 pr time"]')
    for i in tag:
        arrival_time.append(i.text)
except:
    arrival_time.append('Nan')


#source
try:
    tag = driver.find_elements_by_xpath('//div[@class="i-b col-4 no-wrap text-right dtime col-3"]/p')
    for i in tag:
        source.append(i.text)
except:
    source.append('Nan')

#destination
try:
    tag = driver.find_elements_by_xpath('//div[@class="i-b pdd-0 text-left atime col-5"]//p[2]')
    for i in tag:
        destination.append(i.text)
except:
    destination.append('Nan') 

#total stops

try:
    tag = driver.find_elements_by_xpath('//div[@class=" font-lightgrey fs-10 tipsy i-b fs-10"]/span')
    for i in tag:
        total_stops.append(i.text)
except:
    total_stops.append('Nan')

#Price
try:
    tag = driver.find_elements_by_xpath('//div/div[1]/div[4]/div/div[1]/div/label/div/div[2]')
    for i in tag:
        price.append(i.text)
        
except:
    price.append('Nan')
    

#duration
try:
    tag = driver.find_elements_by_xpath('//p[@class="fs-12 bold du mb-2"]')
    for i in tag:
        duration.append(i.text)
        
except:
    duration.append('Nan')
    
len(Airline_name),len(arrival_time),len(dep_time),len(source),len(destination),len(duration),len(total_stops),len(price)
# Out:
# (177, 177, 177, 177, 177, 177, 177, 177)

# %%
#9 June
df_Mum_Del = pd.DataFrame({'Airline Name':Airline_name, 'Departure Date':'9 June 2022','Arrival Time':arrival_time,'Departure Time':dep_time, 'Source':source, 'Destination':destination,'Duration':duration,'Total Stops':total_stops,'Price':price})
df_Mum_Del
# Out:
#     Airline Name Departure Date Arrival Time Departure Time  Source  \
# 0      Air India    9 June 2022        19:10          15:25  Mumbai
# 1       Go First    9 June 2022        20:05          18:00  Mumbai
# 2       Go First    9 June 2022        02:20          00:10  Mumbai
# 3       Go First    9 June 2022        11:35          09:25  Mumbai
# 4       Go First    9 June 2022        13:10          11:00  Mumbai
# ..           ...            ...          ...            ...     ...
# 172     SpiceJet    9 June 2022        21:10          11:15  Mumbai
# 173     SpiceJet    9 June 2022        13:20          06:35  Mumbai
# 174     SpiceJet    9 June 2022        18:35          10:05  Mumbai
# 175     Go First    9 June 2022        16:15          10:50  Mumbai
# 176     Go First    9 June 2022        17:40          10:50  Mumbai
#
#     Destination Duration Total Stops   Price
# 0     New Delhi   3h 45m      1 Stop   7,308
# 1     New Delhi   2h 05m    Non Stop   8,042
# 2     New Delhi   2h 10m    Non Stop   8,042
# 3     New Delhi   2h 10m    Non Stop   8,042
# 4     New Delhi   2h 10m    Non Stop   8,042
# ..          ...      ...         ...     ...
# 172   New Delhi   9h 55m      1 Stop  17,703
# 173   New Delhi   6h 45m      1 Stop  17,950
# 174   New Delhi   8h 30m      1 Stop  19,307
# 175   New Delhi   5h 25m      1 Stop  25,579
# 176   New Delhi   6h 50m      1 Stop  26,313
#
# [177 rows x 9 columns]

# %%
driver.close()

# %%
#loading web driver for Mumbai to banglore for 9 June
driver = webdriver.Chrome('chromedriver.exe') 
driver.get('https://flight.yatra.com/air-search-ui/dom2/trigger?ADT=1&CHD=0&INF=0&class=Economy&destination=BLR&destinationCountry=IN&flexi=0&flight_depart_date=09%2F06%2F2022&hb=0&noOfSegments=1&origin=BOM&originCountry=IN&type=O&unique=929972235941&version=1.1&viewName=normal')
driver.maximize_window()

# %%
last_height = driver.execute_script("return document.documentElement.scrollHeight")

# %%
while True:
    # Scroll down 'till "next load".
    driver.execute_script("window.scrollTo(0, document.documentElement.scrollHeight);")

    # Wait to load everything thus far.
    time.sleep(2)

    # Calculate new scroll height and compare with last scroll height.
    new_height = driver.execute_script("return document.documentElement.scrollHeight")
    if new_height == last_height:
        break
    last_height = new_height

    # One last scroll just in case.
driver.execute_script("window.scrollTo(0, document.documentElement.scrollHeight);")
sleep(2)

# %%
#airline tags
try:
    #tag = driver.find_elements_by_xpath('//div/div[1]/div[1]/div/div[2]/span')
    tag = driver.find_elements_by_xpath('//span[@class="i-b text ellipsis"]')
    for i in tag:
        Airline_name.append(i.text)
        
    l2 = len(Airline_name)
    length_b=l2
except:
    Airline_name.append('Nan')

#Airline_name
#len(Airline_name)


#departure time
try:
    tag = driver.find_elements_by_xpath('//div[@class="i-b pr"]')
    for i in tag:
        dep_time.append(i.text)
except:
    dep_time.append('Nan')


#arrival time
try:
    tag = driver.find_elements_by_xpath('//p[@class="bold fs-15 mb-2 pr time"]')
    for i in tag:
        arrival_time.append(i.text)
except:
    arrival_time.append('Nan')


#source
try:
    tag = driver.find_elements_by_xpath('//div[@class="i-b col-4 no-wrap text-right dtime col-3"]/p')
    for i in tag:
        source.append(i.text)
except:
    source.append('Nan')

#destination
try:
    tag = driver.find_elements_by_xpath('//div[@class="i-b pdd-0 text-left atime col-5"]//p[2]')
    for i in tag:
        destination.append(i.text)
except:
    destination.append('Nan') 

#total stops

try:
    tag = driver.find_elements_by_xpath('//div[@class=" font-lightgrey fs-10 tipsy i-b fs-10"]/span')
    for i in tag:
        total_stops.append(i.text)
except:
    total_stops.append('Nan')

#Price
try:
    tag = driver.find_elements_by_xpath('//div/div[1]/div[4]/div/div[1]/div/label/div/div[2]')
    for i in tag:
        price.append(i.text)
        
except:
    price.append('Nan')
    

#duration
try:
    tag = driver.find_elements_by_xpath('//p[@class="fs-12 bold du mb-2"]')
    for i in tag:
        duration.append(i.text)
        
except:
    duration.append('Nan')
    
len(Airline_name),len(arrival_time),len(dep_time),len(source),len(destination),len(duration),len(total_stops),len(price)
# Out:
# (327, 327, 327, 327, 327, 327, 327, 327)

# %%
#9 june
df_Mum_Banglore = pd.DataFrame({'Airline Name':Airline_name, 'Departure Date':"9 June 2022",'Arrival Time':arrival_time,'Departure Time':dep_time, 'Source':source, 'Destination':destination,'Duration':duration,'Total Stops':total_stops,'Price':price})
df_Mum_Banglore
# Out:
#     Airline Name Departure Date    Arrival Time Departure Time  Source  \
# 0      Air India    9 June 2022           19:10          15:25  Mumbai
# 1       Go First    9 June 2022           20:05          18:00  Mumbai
# 2       Go First    9 June 2022           02:20          00:10  Mumbai
# 3       Go First    9 June 2022           11:35          09:25  Mumbai
# 4       Go First    9 June 2022           13:10          11:00  Mumbai
# ..           ...            ...             ...            ...     ...
# 322      Vistara    9 June 2022  21:50\n+ 1 day          20:55  Mumbai
# 323       IndiGo    9 June 2022           15:50          11:25  Mumbai
# 324      Vistara    9 June 2022           21:50          14:40  Mumbai
# 325      Vistara    9 June 2022           18:15          06:00  Mumbai
# 326    Air India    9 June 2022  16:15\n+ 1 day          11:15  Mumbai
#
#     Destination Duration Total Stops   Price
# 0     New Delhi   3h 45m      1 Stop   7,308
# 1     New Delhi   2h 05m    Non Stop   8,042
# 2     New Delhi   2h 10m    Non Stop   8,042
# 3     New Delhi   2h 10m    Non Stop   8,042
# 4     New Delhi   2h 10m    Non Stop   8,042
# ..          ...      ...         ...     ...
# 322   Bangalore  24h 55m   2 Stop(s)  19,354
# 323   Bangalore   4h 25m      1 Stop  19,646
# 324   Bangalore   7h 10m   2 Stop(s)  21,034
# 325   Bangalore  12h 15m      1 Stop  21,431
# 326   Bangalore  29h 00m   2 Stop(s)  28,308
#
# [327 rows x 9 columns]

# %%
driver.close()

# %%
#10 June Mumbai to Delhi
driver = webdriver.Chrome('chromedriver.exe') 
driver.get('https://flight.yatra.com/air-search-ui/dom2/trigger?type=O&viewName=normal&flexi=0&noOfSegments=1&origin=BOM&originCountry=IN&destination=DEL&destinationCountry=IN&flight_depart_date=10%2F06%2F2022&ADT=1&CHD=0&INF=0&class=Economy&source=fresco-home&unqvaldesktop=1262170230229')
driver.maximize_window()

# %%
last_height = driver.execute_script("return document.documentElement.scrollHeight")

# %%
while True:
    # Scroll down 'till "next load".
    driver.execute_script("window.scrollTo(0, document.documentElement.scrollHeight);")

    # Wait to load everything thus far.
    time.sleep(2)

    # Calculate new scroll height and compare with last scroll height.
    new_height = driver.execute_script("return document.documentElement.scrollHeight")
    if new_height == last_height:
        break
    last_height = new_height

    # One last scroll just in case.
driver.execute_script("window.scrollTo(0, document.documentElement.scrollHeight);")
sleep(2)

# %%
#airline tags
try:
    #tag = driver.find_elements_by_xpath('//div/div[1]/div[1]/div/div[2]/span')
    tag = driver.find_elements_by_xpath('//span[@class="i-b text ellipsis"]')
    for i in tag:
        Airline_name.append(i.text)
        
    l3 = len(Airline_name)
    length=l3
except:
    Airline_name.append('Nan')

#Airline_name
#len(Airline_name)


#departure time
try:
    tag = driver.find_elements_by_xpath('//div[@class="i-b pr"]')
    for i in tag:
        dep_time.append(i.text)
except:
    dep_time.append('Nan')


#arrival time
try:
    tag = driver.find_elements_by_xpath('//p[@class="bold fs-15 mb-2 pr time"]')
    for i in tag:
        arrival_time.append(i.text)
except:
    arrival_time.append('Nan')


#source
try:
    tag = driver.find_elements_by_xpath('//div[@class="i-b col-4 no-wrap text-right dtime col-3"]/p')
    for i in tag:
        source.append(i.text)
except:
    source.append('Nan')

#destination
try:
    tag = driver.find_elements_by_xpath('//div[@class="i-b pdd-0 text-left atime col-5"]//p[2]')
    for i in tag:
        destination.append(i.text)
except:
    destination.append('Nan') 

#total stops

try:
    tag = driver.find_elements_by_xpath('//div[@class=" font-lightgrey fs-10 tipsy i-b fs-10"]/span')
    for i in tag:
        total_stops.append(i.text)
except:
    total_stops.append('Nan')

#Price
try:
    tag = driver.find_elements_by_xpath('//div/div[1]/div[4]/div/div[1]/div/label/div/div[2]')
    for i in tag:
        price.append(i.text)
        
except:
    price.append('Nan')
    

#duration
try:
    tag = driver.find_elements_by_xpath('//p[@class="fs-12 bold du mb-2"]')
    for i in tag:
        duration.append(i.text)
        
except:
    duration.append('Nan')
    
len(Airline_name),len(arrival_time),len(dep_time),len(source),len(destination),len(duration),len(total_stops),len(price)
# Out:
# (504, 504, 504, 504, 504, 504, 504, 504)

# %%
#10 june
df_Mum_Del = pd.DataFrame({'Airline Name':Airline_name, 'Departure Date':"10 June 2022",'Arrival Time':arrival_time,'Departure Time':dep_time, 'Source':source, 'Destination':destination,'Duration':duration,'Total Stops':total_stops,'Price':price})
df_Mum_Del
# Out:
#     Airline Name Departure Date Arrival Time Departure Time  Source  \
# 0      Air India   10 June 2022        19:10          15:25  Mumbai
# 1       Go First   10 June 2022        20:05          18:00  Mumbai
# 2       Go First   10 June 2022        02:20          00:10  Mumbai
# 3       Go First   10 June 2022        11:35          09:25  Mumbai
# 4       Go First   10 June 2022        13:10          11:00  Mumbai
# ..           ...            ...          ...            ...     ...
# 499     SpiceJet   10 June 2022        17:45          11:15  Mumbai
# 500     SpiceJet   10 June 2022        21:10          11:15  Mumbai
# 501     Go First   10 June 2022        20:10          11:30  Mumbai
# 502     Go First   10 June 2022        16:15          10:50  Mumbai
# 503     Go First   10 June 2022        17:40          10:50  Mumbai
#
#     Destination Duration Total Stops   Price
# 0     New Delhi   3h 45m      1 Stop   7,308
# 1     New Delhi   2h 05m    Non Stop   8,042
# 2     New Delhi   2h 10m    Non Stop   8,042
# 3     New Delhi   2h 10m    Non Stop   8,042
# 4     New Delhi   2h 10m    Non Stop   8,042
# ..          ...      ...         ...     ...
# 499   New Delhi   6h 30m      1 Stop  18,333
# 500   New Delhi   9h 55m      1 Stop  18,333
# 501   New Delhi   8h 40m      1 Stop  19,803
# 502   New Delhi   5h 25m      1 Stop  22,113
# 503   New Delhi   6h 50m      1 Stop  22,849
#
# [504 rows x 9 columns]

# %%
driver.close()

# %%
#loading web driver
driver = webdriver.Chrome('chromedriver.exe') 
driver.get('https://flight.yatra.com/air-search-ui/dom2/trigger?type=O&viewName=normal&flexi=0&noOfSegments=1&origin=BOM&originCountry=IN&destination=BLR&destinationCountry=IN&flight_depart_date=10%2F06%2F2022&ADT=1&CHD=0&INF=0&class=Economy&source=fresco-home&unqvaldesktop=1165353587064')
driver.maximize_window()

# %%
last_height = driver.execute_script("return document.documentElement.scrollHeight")

# %%
while True:
    # Scroll down 'till "next load".
    driver.execute_script("window.scrollTo(0, document.documentElement.scrollHeight);")

    # Wait to load everything thus far.
    time.sleep(2)

    # Calculate new scroll height and compare with last scroll height.
    new_height = driver.execute_script("return document.documentElement.scrollHeight")
    if new_height == last_height:
        break
    last_height = new_height

    # One last scroll just in case.
driver.execute_script("window.scrollTo(0, document.documentElement.scrollHeight);")
sleep(2)

# %%
#airline tags
try:
    #tag = driver.find_elements_by_xpath('//div/div[1]/div[1]/div/div[2]/span')
    tag = driver.find_elements_by_xpath('//span[@class="i-b text ellipsis"]')
    for i in tag:
        Airline_name.append(i.text)
        
    l4 = len(Airline_name)
    length=l4
except:
    Airline_name.append('Nan')

#Airline_name
#len(Airline_name)


#departure time
try:
    tag = driver.find_elements_by_xpath('//div[@class="i-b pr"]')
    for i in tag:
        dep_time.append(i.text)
except:
    dep_time.append('Nan')


#arrival time
try:
    tag = driver.find_elements_by_xpath('//p[@class="bold fs-15 mb-2 pr time"]')
    for i in tag:
        arrival_time.append(i.text)
except:
    arrival_time.append('Nan')


#source
try:
    tag = driver.find_elements_by_xpath('//div[@class="i-b col-4 no-wrap text-right dtime col-3"]/p')
    for i in tag:
        source.append(i.text)
except:
    source.append('Nan')

#destination
try:
    tag = driver.find_elements_by_xpath('//div[@class="i-b pdd-0 text-left atime col-5"]//p[2]')
    for i in tag:
        destination.append(i.text)
except:
    destination.append('Nan') 

#total stops

try:
    tag = driver.find_elements_by_xpath('//div[@class=" font-lightgrey fs-10 tipsy i-b fs-10"]/span')
    for i in tag:
        total_stops.append(i.text)
except:
    total_stops.append('Nan')

#Price
try:
    tag = driver.find_elements_by_xpath('//div/div[1]/div[4]/div/div[1]/div/label/div/div[2]')
    for i in tag:
        price.append(i.text)
        
except:
    price.append('Nan')
    

#duration
try:
    tag = driver.find_elements_by_xpath('//p[@class="fs-12 bold du mb-2"]')
    for i in tag:
        duration.append(i.text)
        
except:
    duration.append('Nan')
    
len(Airline_name),len(arrival_time),len(dep_time),len(source),len(destination),len(duration),len(total_stops),len(price)
# Out:
# (653, 653, 653, 653, 653, 653, 653, 653)

# %%
df_Mum_Banglore2 = pd.DataFrame({'Airline Name':Airline_name, 'Departure Date':'10 June 2022','Arrival Time':arrival_time,'Departure Time':dep_time, 'Source':source, 'Destination':destination,'Duration':duration,'Total Stops':total_stops,'Price':price})
df_Mum_Banglore2
# Out:
#     Airline Name Departure Date Arrival Time Departure Time  Source  \
# 0      Air India   10 June 2022        19:10          15:25  Mumbai
# 1       Go First   10 June 2022        20:05          18:00  Mumbai
# 2       Go First   10 June 2022        02:20          00:10  Mumbai
# 3       Go First   10 June 2022        11:35          09:25  Mumbai
# 4       Go First   10 June 2022        13:10          11:00  Mumbai
# ..           ...            ...          ...            ...     ...
# 648      Vistara   10 June 2022        21:50          14:40  Mumbai
# 649      Vistara   10 June 2022        21:50          11:55  Mumbai
# 650      Vistara   10 June 2022        21:50          10:25  Mumbai
# 651      Vistara   10 June 2022        21:50          07:30  Mumbai
# 652      Vistara   10 June 2022        18:15          06:00  Mumbai
#
#     Destination Duration Total Stops   Price
# 0     New Delhi   3h 45m      1 Stop   7,308
# 1     New Delhi   2h 05m    Non Stop   8,042
# 2     New Delhi   2h 10m    Non Stop   8,042
# 3     New Delhi   2h 10m    Non Stop   8,042
# 4     New Delhi   2h 10m    Non Stop   8,042
# ..          ...      ...         ...     ...
# 648   Bangalore   7h 10m   2 Stop(s)  21,034
# 649   Bangalore   9h 55m   2 Stop(s)  21,034
# 650   Bangalore  11h 25m   2 Stop(s)  21,034
# 651   Bangalore  14h 20m   2 Stop(s)  21,034
# 652   Bangalore  12h 15m      1 Stop  22,743
#
# [653 rows x 9 columns]

# %%
driver.close()

# %%
#loading web driver
driver = webdriver.Chrome('chromedriver.exe') 
driver.get('https://flight.yatra.com/air-search-ui/dom2/trigger?ADT=1&CHD=0&INF=0&class=Economy&destination=DEL&destinationCountry=IN&flexi=0&flight_depart_date=11%2F06%2F2022&hb=0&noOfSegments=1&origin=BOM&originCountry=IN&type=O&unique=440453109773&version=1.1&viewName=normal')
driver.maximize_window()

# %%
last_height = driver.execute_script("return document.documentElement.scrollHeight")

# %%
while True:
    # Scroll down 'till "next load".
    driver.execute_script("window.scrollTo(0, document.documentElement.scrollHeight);")

    # Wait to load everything thus far.
    time.sleep(2)

    # Calculate new scroll height and compare with last scroll height.
    new_height = driver.execute_script("return document.documentElement.scrollHeight")
    if new_height == last_height:
        break
    last_height = new_height

    # One last scroll just in case.
driver.execute_script("window.scrollTo(0, document.documentElement.scrollHeight);")
sleep(2)

# %%
#airline tags
try:
    #tag = driver.find_elements_by_xpath('//div/div[1]/div[1]/div/div[2]/span')
    tag = driver.find_elements_by_xpath('//span[@class="i-b text ellipsis"]')
    for i in tag:
        Airline_name.append(i.text)
        
    l5 = len(Airline_name)
    length=l5
except:
    Airline_name.append('Nan')

#Airline_name
#len(Airline_name)


#departure time
try:
    tag = driver.find_elements_by_xpath('//div[@class="i-b pr"]')
    for i in tag:
        dep_time.append(i.text)
except:
    dep_time.append('Nan')


#arrival time
try:
    tag = driver.find_elements_by_xpath('//p[@class="bold fs-15 mb-2 pr time"]')
    for i in tag:
        arrival_time.append(i.text)
except:
    arrival_time.append('Nan')


#source
try:
    tag = driver.find_elements_by_xpath('//div[@class="i-b col-4 no-wrap text-right dtime col-3"]/p')
    for i in tag:
        source.append(i.text)
except:
    source.append('Nan')

#destination
try:
    tag = driver.find_elements_by_xpath('//div[@class="i-b pdd-0 text-left atime col-5"]//p[2]')
    for i in tag:
        destination.append(i.text)
except:
    destination.append('Nan') 

#total stops

try:
    tag = driver.find_elements_by_xpath('//div[@class=" font-lightgrey fs-10 tipsy i-b fs-10"]/span')
    for i in tag:
        total_stops.append(i.text)
except:
    total_stops.append('Nan')

#Price
try:
    tag = driver.find_elements_by_xpath('//div/div[1]/div[4]/div/div[1]/div/label/div/div[2]')
    for i in tag:
        price.append(i.text)
        
except:
    price.append('Nan')
    

#duration
try:
    tag = driver.find_elements_by_xpath('//p[@class="fs-12 bold du mb-2"]')
    for i in tag:
        duration.append(i.text)
        
except:
    duration.append('Nan')
    
len(Airline_name),len(arrival_time),len(dep_time),len(source),len(destination),len(duration),len(total_stops),len(price)
# Out:
# (825, 825, 825, 825, 825, 825, 825, 825)

# %%
df_Mum_Delhi3 = pd.DataFrame({'Airline Name':Airline_name, 'Departure Date':'11 June 2022','Arrival Time':arrival_time,'Departure Time':dep_time, 'Source':source, 'Destination':destination,'Duration':duration,'Total Stops':total_stops,'Price':price})
df_Mum_Delhi3
# Out:
#     Airline Name Departure Date Arrival Time Departure Time  Source  \
# 0      Air India   11 June 2022        19:10          15:25  Mumbai
# 1       Go First   11 June 2022        20:05          18:00  Mumbai
# 2       Go First   11 June 2022        02:20          00:10  Mumbai
# 3       Go First   11 June 2022        11:35          09:25  Mumbai
# 4       Go First   11 June 2022        13:10          11:00  Mumbai
# ..           ...            ...          ...            ...     ...
# 820     SpiceJet   11 June 2022        21:10          10:05  Mumbai
# 821     SpiceJet   11 June 2022        18:35          10:05  Mumbai
# 822     SpiceJet   11 June 2022        13:20          06:45  Mumbai
# 823     Go First   11 June 2022        16:15          10:50  Mumbai
# 824     Go First   11 June 2022        17:40          10:50  Mumbai
#
#     Destination Duration Total Stops   Price
# 0     New Delhi   3h 45m      1 Stop   7,308
# 1     New Delhi   2h 05m    Non Stop   8,042
# 2     New Delhi   2h 10m    Non Stop   8,042
# 3     New Delhi   2h 10m    Non Stop   8,042
# 4     New Delhi   2h 10m    Non Stop   8,042
# ..          ...      ...         ...     ...
# 820   New Delhi  11h 05m      1 Stop  20,321
# 821   New Delhi   8h 30m      1 Stop  21,581
# 822   New Delhi   6h 35m      1 Stop  22,525
# 823   New Delhi   5h 25m      1 Stop  26,209
# 824   New Delhi   6h 50m      1 Stop  26,209
#
# [825 rows x 9 columns]

# %%
driver.close()

# %%
#Mumbai to Banglore 11 June
#loading web driver
driver = webdriver.Chrome('chromedriver.exe') 
driver.get('https://flight.yatra.com/air-search-ui/dom2/trigger?ADT=1&CHD=0&INF=0&class=Economy&destination=BLR&destinationCountry=IN&flexi=0&flight_depart_date=11%2F06%2F2022&hb=0&noOfSegments=1&origin=BOM&originCountry=IN&type=O&unique=286597326343&version=1.1&viewName=normal')
driver.maximize_window()

# %%
last_height = driver.execute_script("return document.documentElement.scrollHeight")

# %%
while True:
    # Scroll down 'till "next load".
    driver.execute_script("window.scrollTo(0, document.documentElement.scrollHeight);")

    # Wait to load everything thus far.
    time.sleep(2)

    # Calculate new scroll height and compare with last scroll height.
    new_height = driver.execute_script("return document.documentElement.scrollHeight")
    if new_height == last_height:
        break
    last_height = new_height

    # One last scroll just in case.
driver.execute_script("window.scrollTo(0, document.documentElement.scrollHeight);")
sleep(2)

# %%
#airline tags
try:
    #tag = driver.find_elements_by_xpath('//div/div[1]/div[1]/div/div[2]/span')
    tag = driver.find_elements_by_xpath('//span[@class="i-b text ellipsis"]')
    for i in tag:
        Airline_name.append(i.text)
        
    l6 = len(Airline_name)
    length=l6
except:
    Airline_name.append('Nan')

#Airline_name
#len(Airline_name)


#departure time
try:
    tag = driver.find_elements_by_xpath('//div[@class="i-b pr"]')
    for i in tag:
        dep_time.append(i.text)
except:
    dep_time.append('Nan')


#arrival time
try:
    tag = driver.find_elements_by_xpath('//p[@class="bold fs-15 mb-2 pr time"]')
    for i in tag:
        arrival_time.append(i.text)
except:
    arrival_time.append('Nan')


#source
try:
    tag = driver.find_elements_by_xpath('//div[@class="i-b col-4 no-wrap text-right dtime col-3"]/p')
    for i in tag:
        source.append(i.text)
except:
    source.append('Nan')

#destination
try:
    tag = driver.find_elements_by_xpath('//div[@class="i-b pdd-0 text-left atime col-5"]//p[2]')
    for i in tag:
        destination.append(i.text)
except:
    destination.append('Nan') 

#total stops

try:
    tag = driver.find_elements_by_xpath('//div[@class=" font-lightgrey fs-10 tipsy i-b fs-10"]/span')
    for i in tag:
        total_stops.append(i.text)
except:
    total_stops.append('Nan')

#Price
try:
    tag = driver.find_elements_by_xpath('//div/div[1]/div[4]/div/div[1]/div/label/div/div[2]')
    for i in tag:
        price.append(i.text)
        
except:
    price.append('Nan')
    

#duration
try:
    tag = driver.find_elements_by_xpath('//p[@class="fs-12 bold du mb-2"]')
    for i in tag:
        duration.append(i.text)
        
except:
    duration.append('Nan')
    
len(Airline_name),len(arrival_time),len(dep_time),len(source),len(destination),len(duration),len(total_stops),len(price)
# Out:
# (975, 975, 975, 975, 975, 975, 975, 975)

# %%
df_Mum_Banglore3 = pd.DataFrame({'Airline Name':Airline_name, 'Departure Date':'11 June 2022','Arrival Time':arrival_time,'Departure Time':dep_time, 'Source':source, 'Destination':destination,'Duration':duration,'Total Stops':total_stops,'Price':price})
df_Mum_Banglore3
# Out:
#     Airline Name Departure Date    Arrival Time Departure Time  Source  \
# 0      Air India   11 June 2022           19:10          15:25  Mumbai
# 1       Go First   11 June 2022           20:05          18:00  Mumbai
# 2       Go First   11 June 2022           02:20          00:10  Mumbai
# 3       Go First   11 June 2022           11:35          09:25  Mumbai
# 4       Go First   11 June 2022           13:10          11:00  Mumbai
# ..           ...            ...             ...            ...     ...
# 970     Go First   11 June 2022  08:35\n+ 1 day          22:30  Mumbai
# 971     Go First   11 June 2022  08:35\n+ 1 day          21:50  Mumbai
# 972      Vistara   11 June 2022           21:50          10:25  Mumbai
# 973      Vistara   11 June 2022           18:15          06:00  Mumbai
# 974    Air India   11 June 2022  16:15\n+ 1 day          11:15  Mumbai
#
#     Destination Duration Total Stops   Price
# 0     New Delhi   3h 45m      1 Stop   7,308
# 1     New Delhi   2h 05m    Non Stop   8,042
# 2     New Delhi   2h 10m    Non Stop   8,042
# 3     New Delhi   2h 10m    Non Stop   8,042
# 4     New Delhi   2h 10m    Non Stop   8,042
# ..          ...      ...         ...     ...
# 970   Bangalore  10h 05m      1 Stop  21,542
# 971   Bangalore  10h 45m      1 Stop  21,542
# 972   Bangalore  11h 25m   2 Stop(s)  21,874
# 973   Bangalore  12h 15m      1 Stop  22,113
# 974   Bangalore  29h 00m   2 Stop(s)  28,413
#
# [975 rows x 9 columns]

# %%
driver.close()

# %% [markdown]
# # Banglore- Mumbai

# %%
#loading web driver
#11 June
driver = webdriver.Chrome('chromedriver.exe') 
driver.get('https://flight.yatra.com/air-search-ui/dom2/trigger?ADT=1&CHD=0&INF=0&class=Economy&destination=BOM&destinationCountry=IN&flexi=0&flight_depart_date=11%2F06%2F2022&hb=0&noOfSegments=1&origin=BLR&originCountry=IN&type=O&unique=127301725361&version=1.1&viewName=normal')
driver.maximize_window()

# %%
last_height = driver.execute_script("return document.documentElement.scrollHeight")

# %%
while True:
    # Scroll down 'till "next load".
    driver.execute_script("window.scrollTo(0, document.documentElement.scrollHeight);")

    # Wait to load everything thus far.
    time.sleep(2)

    # Calculate new scroll height and compare with last scroll height.
    new_height = driver.execute_script("return document.documentElement.scrollHeight")
    if new_height == last_height:
        break
    last_height = new_height

    # One last scroll just in case.
driver.execute_script("window.scrollTo(0, document.documentElement.scrollHeight);")
sleep(2)

# %%
#airline tags
try:
    #tag = driver.find_elements_by_xpath('//div/div[1]/div[1]/div/div[2]/span')
    tag = driver.find_elements_by_xpath('//span[@class="i-b text ellipsis"]')
    for i in tag:
        Airline_name.append(i.text)
        
    l1 = len(Airline_name)
    length=l1
except:
    Airline_name.append('Nan')

#Airline_name
#len(Airline_name)


#departure time
try:
    tag = driver.find_elements_by_xpath('//div[@class="i-b pr"]')
    for i in tag:
        dep_time.append(i.text)
except:
    dep_time.append('Nan')


#arrival time
try:
    tag = driver.find_elements_by_xpath('//p[@class="bold fs-15 mb-2 pr time"]')
    for i in tag:
        arrival_time.append(i.text)
except:
    arrival_time.append('Nan')


#source
try:
    tag = driver.find_elements_by_xpath('//div[@class="i-b col-4 no-wrap text-right dtime col-3"]/p')
    for i in tag:
        source.append(i.text)
except:
    source.append('Nan')

#destination
try:
    tag = driver.find_elements_by_xpath('//div[@class="i-b pdd-0 text-left atime col-5"]//p[2]')
    for i in tag:
        destination.append(i.text)
except:
    destination.append('Nan') 

#total stops

try:
    tag = driver.find_elements_by_xpath('//div[@class=" font-lightgrey fs-10 tipsy i-b fs-10"]/span')
    for i in tag:
        total_stops.append(i.text)
except:
    total_stops.append('Nan')

#Price
try:
    tag = driver.find_elements_by_xpath('//div/div[1]/div[4]/div/div[1]/div/label/div/div[2]')
    for i in tag:
        price.append(i.text)
        
except:
    price.append('Nan')
    

#duration
try:
    tag = driver.find_elements_by_xpath('//p[@class="fs-12 bold du mb-2"]')
    for i in tag:
        duration.append(i.text)
        
except:
    duration.append('Nan')
    
len(Airline_name),len(arrival_time),len(dep_time),len(source),len(destination),len(duration),len(total_stops),len(price)
# Out:
# (1129, 1129, 1129, 1129, 1129, 1129, 1129, 1129)

# %%
df_Banglore_Mum = pd.DataFrame({'Airline Name':Airline_name, 'Departure Date':'11 June 2022','Arrival Time':arrival_time,'Departure Time':dep_time, 'Source':source, 'Destination':destination,'Duration':duration,'Total Stops':total_stops,'Price':price})
df_Banglore_Mum
# Out:
#      Airline Name Departure Date    Arrival Time Departure Time     Source  \
# 0       Air India   11 June 2022           19:10          15:25     Mumbai
# 1        Go First   11 June 2022           20:05          18:00     Mumbai
# 2        Go First   11 June 2022           02:20          00:10     Mumbai
# 3        Go First   11 June 2022           11:35          09:25     Mumbai
# 4        Go First   11 June 2022           13:10          11:00     Mumbai
# ...           ...            ...             ...            ...        ...
# 1124      Vistara   11 June 2022           17:40          11:30  Bangalore
# 1125    Air India   11 June 2022  16:25\n+ 1 day          10:00  Bangalore
# 1126    Air India   11 June 2022  16:25\n+ 1 day          17:00  Bangalore
# 1127    Air India   11 June 2022  16:25\n+ 1 day          13:20  Bangalore
# 1128      Vistara   11 June 2022           22:20          11:30  Bangalore
#
#      Destination Duration Total Stops   Price
# 0      New Delhi   3h 45m      1 Stop   7,308
# 1      New Delhi   2h 05m    Non Stop   8,042
# 2      New Delhi   2h 10m    Non Stop   8,042
# 3      New Delhi   2h 10m    Non Stop   8,042
# 4      New Delhi   2h 10m    Non Stop   8,042
# ...          ...      ...         ...     ...
# 1124      Mumbai   6h 10m      1 Stop  20,704
# 1125      Mumbai  30h 25m   2 Stop(s)  20,844
# 1126      Mumbai  23h 25m   2 Stop(s)  21,768
# 1127      Mumbai  27h 05m   2 Stop(s)  21,768
# 1128      Mumbai  10h 50m      1 Stop  28,999
#
# [1129 rows x 9 columns]

# %%
driver.close()

# %%
#loading web driver
#10 June
driver = webdriver.Chrome('chromedriver.exe') 
driver.get('https://flight.yatra.com/air-search-ui/dom2/trigger?ADT=1&CHD=0&INF=0&class=Economy&destination=BOM&destinationCountry=IN&flexi=0&flight_depart_date=10%2F06%2F2022&hb=0&noOfSegments=1&origin=BLR&originCountry=IN&type=O&unique=272338209164&version=1.1&viewName=normal')
driver.maximize_window()

# %%
last_height = driver.execute_script("return document.documentElement.scrollHeight")

# %%
while True:
    # Scroll down 'till "next load".
    driver.execute_script("window.scrollTo(0, document.documentElement.scrollHeight);")

    # Wait to load everything thus far.
    time.sleep(2)

    # Calculate new scroll height and compare with last scroll height.
    new_height = driver.execute_script("return document.documentElement.scrollHeight")
    if new_height == last_height:
        break
    last_height = new_height

    # One last scroll just in case.
driver.execute_script("window.scrollTo(0, document.documentElement.scrollHeight);")
sleep(2)

# %%
#airline tags
try:
    #tag = driver.find_elements_by_xpath('//div/div[1]/div[1]/div/div[2]/span')
    tag = driver.find_elements_by_xpath('//span[@class="i-b text ellipsis"]')
    for i in tag:
        Airline_name.append(i.text)
        
    l1 = len(Airline_name)
    length=l1
except:
    Airline_name.append('Nan')

#Airline_name
#len(Airline_name)


#departure time
try:
    tag = driver.find_elements_by_xpath('//div[@class="i-b pr"]')
    for i in tag:
        dep_time.append(i.text)
except:
    dep_time.append('Nan')


#arrival time
try:
    tag = driver.find_elements_by_xpath('//p[@class="bold fs-15 mb-2 pr time"]')
    for i in tag:
        arrival_time.append(i.text)
except:
    arrival_time.append('Nan')


#source
try:
    tag = driver.find_elements_by_xpath('//div[@class="i-b col-4 no-wrap text-right dtime col-3"]/p')
    for i in tag:
        source.append(i.text)
except:
    source.append('Nan')

#destination
try:
    tag = driver.find_elements_by_xpath('//div[@class="i-b pdd-0 text-left atime col-5"]//p[2]')
    for i in tag:
        destination.append(i.text)
except:
    destination.append('Nan') 

#total stops

try:
    tag = driver.find_elements_by_xpath('//div[@class=" font-lightgrey fs-10 tipsy i-b fs-10"]/span')
    for i in tag:
        total_stops.append(i.text)
except:
    total_stops.append('Nan')

#Price
try:
    tag = driver.find_elements_by_xpath('//div/div[1]/div[4]/div/div[1]/div/label/div/div[2]')
    for i in tag:
        price.append(i.text)
        
except:
    price.append('Nan')
    

#duration
try:
    tag = driver.find_elements_by_xpath('//p[@class="fs-12 bold du mb-2"]')
    for i in tag:
        duration.append(i.text)
        
except:
    duration.append('Nan')
    
len(Airline_name),len(arrival_time),len(dep_time),len(source),len(destination),len(duration),len(total_stops),len(price)
# Out:
# (1279, 1279, 1279, 1279, 1279, 1279, 1279, 1279)

# %%
df_Banglore_Mum2 = pd.DataFrame({'Airline Name':Airline_name, 'Departure Date':'10 June 2022','Arrival Time':arrival_time,'Departure Time':dep_time, 'Source':source, 'Destination':destination,'Duration':duration,'Total Stops':total_stops,'Price':price})
df_Banglore_Mum2
# Out:
#      Airline Name Departure Date Arrival Time Departure Time     Source  \
# 0       Air India   10 June 2022        19:10          15:25     Mumbai
# 1        Go First   10 June 2022        20:05          18:00     Mumbai
# 2        Go First   10 June 2022        02:20          00:10     Mumbai
# 3        Go First   10 June 2022        11:35          09:25     Mumbai
# 4        Go First   10 June 2022        13:10          11:00     Mumbai
# ...           ...            ...          ...            ...        ...
# 1274      Vistara   10 June 2022        23:30          17:45  Bangalore
# 1275      Vistara   10 June 2022        16:30          07:45  Bangalore
# 1276       IndiGo   10 June 2022        14:30          06:35  Bangalore
# 1277      Vistara   10 June 2022        21:55          11:30  Bangalore
# 1278      Vistara   10 June 2022        22:20          11:30  Bangalore
#
#      Destination Duration Total Stops   Price
# 0      New Delhi   3h 45m      1 Stop   7,308
# 1      New Delhi   2h 05m    Non Stop   8,042
# 2      New Delhi   2h 10m    Non Stop   8,042
# 3      New Delhi   2h 10m    Non Stop   8,042
# 4      New Delhi   2h 10m    Non Stop   8,042
# ...          ...      ...         ...     ...
# 1274      Mumbai   5h 45m      1 Stop  20,284
# 1275      Mumbai   8h 45m   2 Stop(s)  20,738
# 1276      Mumbai   7h 55m      1 Stop  20,967
# 1277      Mumbai  10h 25m      1 Stop  21,019
# 1278      Mumbai  10h 50m      1 Stop  22,909
#
# [1279 rows x 9 columns]

# %%
driver.close()

# %%
#loading web driver
#9 June
driver = webdriver.Chrome('chromedriver.exe') 
driver.get('https://flight.yatra.com/air-search-ui/dom2/trigger?ADT=1&CHD=0&INF=0&class=Economy&destination=BOM&destinationCountry=IN&flexi=0&flight_depart_date=09%2F06%2F2022&hb=0&noOfSegments=1&origin=BLR&originCountry=IN&type=O&unique=1285015046213&version=1.1&viewName=normal')
driver.maximize_window()

# %%
last_height = driver.execute_script("return document.documentElement.scrollHeight")

# %%
while True:
    # Scroll down 'till "next load".
    driver.execute_script("window.scrollTo(0, document.documentElement.scrollHeight);")

    # Wait to load everything thus far.
    time.sleep(2)

    # Calculate new scroll height and compare with last scroll height.
    new_height = driver.execute_script("return document.documentElement.scrollHeight")
    if new_height == last_height:
        break
    last_height = new_height

    # One last scroll just in case.
driver.execute_script("window.scrollTo(0, document.documentElement.scrollHeight);")
sleep(2)

# %%
#airline tags
try:
    #tag = driver.find_elements_by_xpath('//div/div[1]/div[1]/div/div[2]/span')
    tag = driver.find_elements_by_xpath('//span[@class="i-b text ellipsis"]')
    for i in tag:
        Airline_name.append(i.text)
        
    l1 = len(Airline_name)
    length=l1
except:
    Airline_name.append('Nan')

#Airline_name
#len(Airline_name)


#departure time
try:
    tag = driver.find_elements_by_xpath('//div[@class="i-b pr"]')
    for i in tag:
        dep_time.append(i.text)
except:
    dep_time.append('Nan')


#arrival time
try:
    tag = driver.find_elements_by_xpath('//p[@class="bold fs-15 mb-2 pr time"]')
    for i in tag:
        arrival_time.append(i.text)
except:
    arrival_time.append('Nan')


#source
try:
    tag = driver.find_elements_by_xpath('//div[@class="i-b col-4 no-wrap text-right dtime col-3"]/p')
    for i in tag:
        source.append(i.text)
except:
    source.append('Nan')

#destination
try:
    tag = driver.find_elements_by_xpath('//div[@class="i-b pdd-0 text-left atime col-5"]//p[2]')
    for i in tag:
        destination.append(i.text)
except:
    destination.append('Nan') 

#total stops

try:
    tag = driver.find_elements_by_xpath('//div[@class=" font-lightgrey fs-10 tipsy i-b fs-10"]/span')
    for i in tag:
        total_stops.append(i.text)
except:
    total_stops.append('Nan')

#Price
try:
    tag = driver.find_elements_by_xpath('//div/div[1]/div[4]/div/div[1]/div/label/div/div[2]')
    for i in tag:
        price.append(i.text)
        
except:
    price.append('Nan')
    

#duration
try:
    tag = driver.find_elements_by_xpath('//p[@class="fs-12 bold du mb-2"]')
    for i in tag:
        duration.append(i.text)
        
except:
    duration.append('Nan')
    
len(Airline_name),len(arrival_time),len(dep_time),len(source),len(destination),len(duration),len(total_stops),len(price)
# Out:
# (1432, 1432, 1432, 1432, 1432, 1432, 1432, 1432)

# %%
df_Banglore_Mum3 = pd.DataFrame({'Airline Name':Airline_name, 'Departure Date':'9 June 2022','Arrival Time':arrival_time,'Departure Time':dep_time, 'Source':source, 'Destination':destination,'Duration':duration,'Total Stops':total_stops,'Price':price})
df_Banglore_Mum3
# Out:
#      Airline Name Departure Date    Arrival Time Departure Time     Source  \
# 0       Air India    9 June 2022           19:10          15:25     Mumbai
# 1        Go First    9 June 2022           20:05          18:00     Mumbai
# 2        Go First    9 June 2022           02:20          00:10     Mumbai
# 3        Go First    9 June 2022           11:35          09:25     Mumbai
# 4        Go First    9 June 2022           13:10          11:00     Mumbai
# ...           ...            ...             ...            ...        ...
# 1427    Air India    9 June 2022  16:25\n+ 1 day          21:20  Bangalore
# 1428    Air India    9 June 2022  16:25\n+ 1 day          17:00  Bangalore
# 1429    Air India    9 June 2022  16:25\n+ 1 day          13:20  Bangalore
# 1430    Air India    9 June 2022           19:15          06:10  Bangalore
# 1431      Vistara    9 June 2022           22:20          11:30  Bangalore
#
#      Destination Duration Total Stops   Price
# 0      New Delhi   3h 45m      1 Stop   7,308
# 1      New Delhi   2h 05m    Non Stop   8,042
# 2      New Delhi   2h 10m    Non Stop   8,042
# 3      New Delhi   2h 10m    Non Stop   8,042
# 4      New Delhi   2h 10m    Non Stop   8,042
# ...          ...      ...         ...     ...
# 1427      Mumbai  19h 05m   2 Stop(s)  19,290
# 1428      Mumbai  23h 25m   2 Stop(s)  19,290
# 1429      Mumbai  27h 05m   2 Stop(s)  19,290
# 1430      Mumbai  13h 05m   2 Stop(s)  19,635
# 1431      Mumbai  10h 50m      1 Stop  20,862
#
# [1432 rows x 9 columns]

# %%
driver.close()

# %% [markdown]
# # Mumbai - Delhi

# %%
#loading web driver
driver = webdriver.Chrome('chromedriver.exe') 
driver.get('https://flight.yatra.com/air-search-ui/dom2/trigger?ADT=1&CHD=0&INF=0&class=Economy&destination=DEL&destinationCountry=IN&flexi=0&flight_depart_date=09%2F06%2F2022&hb=0&noOfSegments=1&origin=BOM&originCountry=IN&type=O&unique=868252829041&version=1.1&viewName=normal')
driver.maximize_window()

# %%
last_height = driver.execute_script("return document.documentElement.scrollHeight")

# %%
while True:
    # Scroll down 'till "next load".
    driver.execute_script("window.scrollTo(0, document.documentElement.scrollHeight);")

    # Wait to load everything thus far.
    time.sleep(2)

    # Calculate new scroll height and compare with last scroll height.
    new_height = driver.execute_script("return document.documentElement.scrollHeight")
    if new_height == last_height:
        break
    last_height = new_height

    # One last scroll just in case.
driver.execute_script("window.scrollTo(0, document.documentElement.scrollHeight);")
sleep(2)

# %%
#airline tags
try:
    #tag = driver.find_elements_by_xpath('//div/div[1]/div[1]/div/div[2]/span')
    tag = driver.find_elements_by_xpath('//span[@class="i-b text ellipsis"]')
    for i in tag:
        Airline_name.append(i.text)
        
    l1 = len(Airline_name)
    length=l1
except:
    Airline_name.append('Nan')

#Airline_name
#len(Airline_name)


#departure time
try:
    tag = driver.find_elements_by_xpath('//div[@class="i-b pr"]')
    for i in tag:
        dep_time.append(i.text)
except:
    dep_time.append('Nan')


#arrival time
try:
    tag = driver.find_elements_by_xpath('//p[@class="bold fs-15 mb-2 pr time"]')
    for i in tag:
        arrival_time.append(i.text)
except:
    arrival_time.append('Nan')


#source
try:
    tag = driver.find_elements_by_xpath('//div[@class="i-b col-4 no-wrap text-right dtime col-3"]/p')
    for i in tag:
        source.append(i.text)
except:
    source.append('Nan')

#destination
try:
    tag = driver.find_elements_by_xpath('//div[@class="i-b pdd-0 text-left atime col-5"]//p[2]')
    for i in tag:
        destination.append(i.text)
except:
    destination.append('Nan') 

#total stops

try:
    tag = driver.find_elements_by_xpath('//div[@class=" font-lightgrey fs-10 tipsy i-b fs-10"]/span')
    for i in tag:
        total_stops.append(i.text)
except:
    total_stops.append('Nan')

#Price
try:
    tag = driver.find_elements_by_xpath('//div/div[1]/div[4]/div/div[1]/div/label/div/div[2]')
    for i in tag:
        price.append(i.text)
        
except:
    price.append('Nan')
    

#duration
try:
    tag = driver.find_elements_by_xpath('//p[@class="fs-12 bold du mb-2"]')
    for i in tag:
        duration.append(i.text)
        
except:
    duration.append('Nan')
    
len(Airline_name),len(arrival_time),len(dep_time),len(source),len(destination),len(duration),len(total_stops),len(price)
# Out:
# (1609, 1609, 1609, 1609, 1609, 1609, 1609, 1609)

# %%
df_Mum_Delhi = pd.DataFrame({'Airline Name':Airline_name, 'Departure Date':'9 June 2022','Arrival Time':arrival_time,'Departure Time':dep_time, 'Source':source, 'Destination':destination,'Duration':duration,'Total Stops':total_stops,'Price':price})
df_Mum_Delhi
# Out:
#      Airline Name Departure Date Arrival Time Departure Time  Source  \
# 0       Air India    9 June 2022        19:10          15:25  Mumbai
# 1        Go First    9 June 2022        20:05          18:00  Mumbai
# 2        Go First    9 June 2022        02:20          00:10  Mumbai
# 3        Go First    9 June 2022        11:35          09:25  Mumbai
# 4        Go First    9 June 2022        13:10          11:00  Mumbai
# ...           ...            ...          ...            ...     ...
# 1604     SpiceJet    9 June 2022        21:10          11:15  Mumbai
# 1605     SpiceJet    9 June 2022        13:20          06:35  Mumbai
# 1606     SpiceJet    9 June 2022        18:35          10:05  Mumbai
# 1607     Go First    9 June 2022        16:15          10:50  Mumbai
# 1608     Go First    9 June 2022        17:40          10:50  Mumbai
#
#      Destination Duration Total Stops   Price
# 0      New Delhi   3h 45m      1 Stop   7,308
# 1      New Delhi   2h 05m    Non Stop   8,042
# 2      New Delhi   2h 10m    Non Stop   8,042
# 3      New Delhi   2h 10m    Non Stop   8,042
# 4      New Delhi   2h 10m    Non Stop   8,042
# ...          ...      ...         ...     ...
# 1604   New Delhi   9h 55m      1 Stop  17,703
# 1605   New Delhi   6h 45m      1 Stop  17,950
# 1606   New Delhi   8h 30m      1 Stop  19,307
# 1607   New Delhi   5h 25m      1 Stop  25,579
# 1608   New Delhi   6h 50m      1 Stop  26,313
#
# [1609 rows x 9 columns]

# %%
driver.close()

# %%
#loading web driver
#10 June
driver = webdriver.Chrome('chromedriver.exe') 
driver.get('https://flight.yatra.com/air-search-ui/dom2/trigger?ADT=1&CHD=0&INF=0&class=Economy&destination=DEL&destinationCountry=IN&flexi=0&flight_depart_date=10%2F06%2F2022&hb=0&noOfSegments=1&origin=BOM&originCountry=IN&type=O&unique=1381184119700&version=1.1&viewName=normal')
driver.maximize_window()

# %%
last_height = driver.execute_script("return document.documentElement.scrollHeight")

# %%
while True:
    # Scroll down 'till "next load".
    driver.execute_script("window.scrollTo(0, document.documentElement.scrollHeight);")

    # Wait to load everything thus far.
    time.sleep(2)

    # Calculate new scroll height and compare with last scroll height.
    new_height = driver.execute_script("return document.documentElement.scrollHeight")
    if new_height == last_height:
        break
    last_height = new_height

    # One last scroll just in case.
driver.execute_script("window.scrollTo(0, document.documentElement.scrollHeight);")
sleep(2)

# %%
#airline tags
try:
    #tag = driver.find_elements_by_xpath('//div/div[1]/div[1]/div/div[2]/span')
    tag = driver.find_elements_by_xpath('//span[@class="i-b text ellipsis"]')
    for i in tag:
        Airline_name.append(i.text)
        
    l8 = len(Airline_name)
    length=l8
except:
    Airline_name.append('Nan')

#Airline_name
#len(Airline_name)


#departure time
try:
    tag = driver.find_elements_by_xpath('//div[@class="i-b pr"]')
    for i in tag:
        dep_time.append(i.text)
except:
    dep_time.append('Nan')


#arrival time
try:
    tag = driver.find_elements_by_xpath('//p[@class="bold fs-15 mb-2 pr time"]')
    for i in tag:
        arrival_time.append(i.text)
except:
    arrival_time.append('Nan')


#source
try:
    tag = driver.find_elements_by_xpath('//div[@class="i-b col-4 no-wrap text-right dtime col-3"]/p')
    for i in tag:
        source.append(i.text)
except:
    source.append('Nan')

#destination
try:
    tag = driver.find_elements_by_xpath('//div[@class="i-b pdd-0 text-left atime col-5"]//p[2]')
    for i in tag:
        destination.append(i.text)
except:
    destination.append('Nan') 

#total stops

try:
    tag = driver.find_elements_by_xpath('//div[@class=" font-lightgrey fs-10 tipsy i-b fs-10"]/span')
    for i in tag:
        total_stops.append(i.text)
except:
    total_stops.append('Nan')

#Price
try:
    tag = driver.find_elements_by_xpath('//div/div[1]/div[4]/div/div[1]/div/label/div/div[2]')
    for i in tag:
        price.append(i.text)
        
except:
    price.append('Nan')
    

#duration
try:
    tag = driver.find_elements_by_xpath('//p[@class="fs-12 bold du mb-2"]')
    for i in tag:
        duration.append(i.text)
        
except:
    duration.append('Nan')
    
len(Airline_name),len(arrival_time),len(dep_time),len(source),len(destination),len(duration),len(total_stops),len(price)
# Out:
# (1786, 1786, 1786, 1786, 1786, 1786, 1786, 1786)

# %%
df_Mum_Delhi2 = pd.DataFrame({'Airline Name':Airline_name, 'Departure Date':'10 June 2022','Arrival Time':arrival_time,'Departure Time':dep_time, 'Source':source, 'Destination':destination,'Duration':duration,'Total Stops':total_stops,'Price':price})
df_Mum_Delhi2
# Out:
#      Airline Name Departure Date Arrival Time Departure Time  Source  \
# 0       Air India   10 June 2022        19:10          15:25  Mumbai
# 1        Go First   10 June 2022        20:05          18:00  Mumbai
# 2        Go First   10 June 2022        02:20          00:10  Mumbai
# 3        Go First   10 June 2022        11:35          09:25  Mumbai
# 4        Go First   10 June 2022        13:10          11:00  Mumbai
# ...           ...            ...          ...            ...     ...
# 1781     SpiceJet   10 June 2022        17:45          11:15  Mumbai
# 1782     SpiceJet   10 June 2022        21:10          11:15  Mumbai
# 1783     Go First   10 June 2022        20:10          11:30  Mumbai
# 1784     Go First   10 June 2022        16:15          10:50  Mumbai
# 1785     Go First   10 June 2022        17:40          10:50  Mumbai
#
#      Destination Duration Total Stops   Price
# 0      New Delhi   3h 45m      1 Stop   7,308
# 1      New Delhi   2h 05m    Non Stop   8,042
# 2      New Delhi   2h 10m    Non Stop   8,042
# 3      New Delhi   2h 10m    Non Stop   8,042
# 4      New Delhi   2h 10m    Non Stop   8,042
# ...          ...      ...         ...     ...
# 1781   New Delhi   6h 30m      1 Stop  18,333
# 1782   New Delhi   9h 55m      1 Stop  18,333
# 1783   New Delhi   8h 40m      1 Stop  19,803
# 1784   New Delhi   5h 25m      1 Stop  22,113
# 1785   New Delhi   6h 50m      1 Stop  22,849
#
# [1786 rows x 9 columns]

# %%
driver.close()

# %%
#loading web driver
#11 June
driver = webdriver.Chrome('chromedriver.exe')
driver.get('https://flight.yatra.com/air-search-ui/dom2/trigger?ADT=1&CHD=0&INF=0&class=Economy&destination=DEL&destinationCountry=IN&flexi=0&flight_depart_date=11%2F06%2F2022&hb=0&noOfSegments=1&origin=BOM&originCountry=IN&type=O&unique=793862637855&version=1.1&viewName=normal')
driver.maximize_window()

# %%
last_height = driver.execute_script("return document.documentElement.scrollHeight")

# %%
while True:
    # Scroll down 'till "next load".
    driver.execute_script("window.scrollTo(0, document.documentElement.scrollHeight);")

    # Wait to load everything thus far.
    time.sleep(2)

    # Calculate new scroll height and compare with last scroll height.
    new_height = driver.execute_script("return document.documentElement.scrollHeight")
    if new_height == last_height:
        break
    last_height = new_height

    # One last scroll just in case.
driver.execute_script("window.scrollTo(0, document.documentElement.scrollHeight);")
sleep(2)

# %%
#airline tags
try:
    #tag = driver.find_elements_by_xpath('//div/div[1]/div[1]/div/div[2]/span')
    tag = driver.find_elements_by_xpath('//span[@class="i-b text ellipsis"]')
    for i in tag:
        Airline_name.append(i.text)
        
    l9 = len(Airline_name)
    length=l9
except:
    Airline_name.append('Nan')

#Airline_name
#len(Airline_name)


#departure time
try:
    tag = driver.find_elements_by_xpath('//div[@class="i-b pr"]')
    for i in tag:
        dep_time.append(i.text)
except:
    dep_time.append('Nan')


#arrival time
try:
    tag = driver.find_elements_by_xpath('//p[@class="bold fs-15 mb-2 pr time"]')
    for i in tag:
        arrival_time.append(i.text)
except:
    arrival_time.append('Nan')


#source
try:
    tag = driver.find_elements_by_xpath('//div[@class="i-b col-4 no-wrap text-right dtime col-3"]/p')
    for i in tag:
        source.append(i.text)
except:
    source.append('Nan')

#destination
try:
    tag = driver.find_elements_by_xpath('//div[@class="i-b pdd-0 text-left atime col-5"]//p[2]')
    for i in tag:
        destination.append(i.text)
except:
    destination.append('Nan') 

#total stops

try:
    tag = driver.find_elements_by_xpath('//div[@class=" font-lightgrey fs-10 tipsy i-b fs-10"]/span')
    for i in tag:
        total_stops.append(i.text)
except:
    total_stops.append('Nan')

#Price
try:
    tag = driver.find_elements_by_xpath('//div/div[1]/div[4]/div/div[1]/div/label/div/div[2]')
    for i in tag:
        price.append(i.text)
        
except:
    price.append('Nan')
    

#duration
try:
    tag = driver.find_elements_by_xpath('//p[@class="fs-12 bold du mb-2"]')
    for i in tag:
        duration.append(i.text)
        
except:
    duration.append('Nan')
    
len(Airline_name),len(arrival_time),len(dep_time),len(source),len(destination),len(duration),len(total_stops),len(price)
# Out:
# (1958, 1958, 1958, 1958, 1958, 1958, 1958, 1958)

# %%
df_Mum_Delhi3 = pd.DataFrame({'Airline Name':Airline_name, 'Departure Date':'11 June 2022','Arrival Time':arrival_time,'Departure Time':dep_time, 'Source':source, 'Destination':destination,'Duration':duration,'Total Stops':total_stops,'Price':price})
df_Mum_Delhi3
# Out:
#      Airline Name Departure Date Arrival Time Departure Time  Source  \
# 0       Air India   11 June 2022        19:10          15:25  Mumbai
# 1        Go First   11 June 2022        20:05          18:00  Mumbai
# 2        Go First   11 June 2022        02:20          00:10  Mumbai
# 3        Go First   11 June 2022        11:35          09:25  Mumbai
# 4        Go First   11 June 2022        13:10          11:00  Mumbai
# ...           ...            ...          ...            ...     ...
# 1953     SpiceJet   11 June 2022        21:10          10:05  Mumbai
# 1954     SpiceJet   11 June 2022        18:35          10:05  Mumbai
# 1955     SpiceJet   11 June 2022        13:20          06:45  Mumbai
# 1956     Go First   11 June 2022        16:15          10:50  Mumbai
# 1957     Go First   11 June 2022        17:40          10:50  Mumbai
#
#      Destination Duration Total Stops   Price
# 0      New Delhi   3h 45m      1 Stop   7,308
# 1      New Delhi   2h 05m    Non Stop   8,042
# 2      New Delhi   2h 10m    Non Stop   8,042
# 3      New Delhi   2h 10m    Non Stop   8,042
# 4      New Delhi   2h 10m    Non Stop   8,042
# ...          ...      ...         ...     ...
# 1953   New Delhi  11h 05m      1 Stop  20,321
# 1954   New Delhi   8h 30m      1 Stop  21,581
# 1955   New Delhi   6h 35m      1 Stop  22,525
# 1956   New Delhi   5h 25m      1 Stop  26,209
# 1957   New Delhi   6h 50m      1 Stop  26,209
#
# [1958 rows x 9 columns]

# %%
driver.close()

# %% [markdown]
# # Chennai-Kochi

# %%
#loading web driver
#9 June
driver = webdriver.Chrome('chromedriver.exe')
driver.get('https://flight.yatra.com/air-search-ui/dom2/trigger?ADT=1&CHD=0&INF=0&class=Economy&destination=COK&destinationCountry=IN&flexi=0&flight_depart_date=09%2F06%2F2022&hb=0&noOfSegments=1&origin=MAA&originCountry=IN&type=O&unique=1095279809949&version=1.1&viewName=normal')
driver.maximize_window()

# %%
last_height = driver.execute_script("return document.documentElement.scrollHeight")

# %%
while True:
    # Scroll down 'till "next load".
    driver.execute_script("window.scrollTo(0, document.documentElement.scrollHeight);")

    # Wait to load everything thus far.
    time.sleep(2)

    # Calculate new scroll height and compare with last scroll height.
    new_height = driver.execute_script("return document.documentElement.scrollHeight")
    if new_height == last_height:
        break
    last_height = new_height

    # One last scroll just in case.
driver.execute_script("window.scrollTo(0, document.documentElement.scrollHeight);")
sleep(2)

# %%
#airline tags
try:
    #tag = driver.find_elements_by_xpath('//div/div[1]/div[1]/div/div[2]/span')
    tag = driver.find_elements_by_xpath('//span[@class="i-b text ellipsis"]')
    for i in tag:
        Airline_name.append(i.text)
        
    l1 = len(Airline_name)
    length=l1
except:
    Airline_name.append('Nan')

#Airline_name
#len(Airline_name)


#departure time
try:
    tag = driver.find_elements_by_xpath('//div[@class="i-b pr"]')
    for i in tag:
        dep_time.append(i.text)
except:
    dep_time.append('Nan')


#arrival time
try:
    tag = driver.find_elements_by_xpath('//p[@class="bold fs-15 mb-2 pr time"]')
    for i in tag:
        arrival_time.append(i.text)
except:
    arrival_time.append('Nan')


#source
try:
    tag = driver.find_elements_by_xpath('//div[@class="i-b col-4 no-wrap text-right dtime col-3"]/p')
    for i in tag:
        source.append(i.text)
except:
    source.append('Nan')

#destination
try:
    tag = driver.find_elements_by_xpath('//div[@class="i-b pdd-0 text-left atime col-5"]//p[2]')
    for i in tag:
        destination.append(i.text)
except:
    destination.append('Nan') 

#total stops

try:
    tag = driver.find_elements_by_xpath('//div[@class=" font-lightgrey fs-10 tipsy i-b fs-10"]/span')
    for i in tag:
        total_stops.append(i.text)
except:
    total_stops.append('Nan')

#Price
try:
    tag = driver.find_elements_by_xpath('//div/div[1]/div[4]/div/div[1]/div/label/div/div[2]')
    for i in tag:
        price.append(i.text)
        
except:
    price.append('Nan')
    

#duration
try:
    tag = driver.find_elements_by_xpath('//p[@class="fs-12 bold du mb-2"]')
    for i in tag:
        duration.append(i.text)
        
except:
    duration.append('Nan')
    
len(Airline_name),len(arrival_time),len(dep_time),len(source),len(destination),len(duration),len(total_stops),len(price)
# Out:
# (2016, 2016, 2016, 2016, 2016, 2016, 2016, 2016)

# %%
df_Chennai_Kochi = pd.DataFrame({'Airline Name':Airline_name, 'Departure Date':'9 June 2022','Arrival Time':arrival_time,'Departure Time':dep_time, 'Source':source, 'Destination':destination,'Duration':duration,'Total Stops':total_stops,'Price':price})
df_Chennai_Kochi
# Out:
#      Airline Name Departure Date    Arrival Time Departure Time   Source  \
# 0       Air India    9 June 2022           19:10          15:25   Mumbai
# 1        Go First    9 June 2022           20:05          18:00   Mumbai
# 2        Go First    9 June 2022           02:20          00:10   Mumbai
# 3        Go First    9 June 2022           11:35          09:25   Mumbai
# 4        Go First    9 June 2022           13:10          11:00   Mumbai
# ...           ...            ...             ...            ...      ...
# 2011      Vistara    9 June 2022  08:40\n+ 1 day          17:15  Chennai
# 2012      Vistara    9 June 2022           19:10          09:45  Chennai
# 2013      Vistara    9 June 2022           19:10          07:00  Chennai
# 2014      Vistara    9 June 2022           19:10          07:00  Chennai
# 2015      Vistara    9 June 2022           19:10          07:00  Chennai
#
#      Destination Duration Total Stops   Price
# 0      New Delhi   3h 45m      1 Stop   7,308
# 1      New Delhi   2h 05m    Non Stop   8,042
# 2      New Delhi   2h 10m    Non Stop   8,042
# 3      New Delhi   2h 10m    Non Stop   8,042
# 4      New Delhi   2h 10m    Non Stop   8,042
# ...          ...      ...         ...     ...
# 2011       Kochi  15h 25m      1 Stop  23,683
# 2012       Kochi   9h 25m   2 Stop(s)  24,074
# 2013       Kochi  12h 10m   2 Stop(s)  24,074
# 2014       Kochi  12h 10m   2 Stop(s)  24,074
# 2015       Kochi  12h 10m   2 Stop(s)  24,074
#
# [2016 rows x 9 columns]

# %%
driver.close()

# %%
#loading web driver
#11 June
driver = webdriver.Chrome('chromedriver.exe')
driver.get('https://flight.yatra.com/air-search-ui/dom2/trigger?ADT=1&CHD=0&INF=0&class=Economy&destination=COK&destinationCountry=IN&flexi=0&flight_depart_date=11%2F06%2F2022&hb=0&noOfSegments=1&origin=MAA&originCountry=IN&type=O&unique=1506990724168&version=1.1&viewName=normal')
driver.maximize_window()

# %%
last_height = driver.execute_script("return document.documentElement.scrollHeight")

# %%
while True:
    # Scroll down 'till "next load".
    driver.execute_script("window.scrollTo(0, document.documentElement.scrollHeight);")

    # Wait to load everything thus far.
    time.sleep(2)

    # Calculate new scroll height and compare with last scroll height.
    new_height = driver.execute_script("return document.documentElement.scrollHeight")
    if new_height == last_height:
        break
    last_height = new_height

    # One last scroll just in case.
driver.execute_script("window.scrollTo(0, document.documentElement.scrollHeight);")
sleep(2)

# %%
#airline tags
try:
    #tag = driver.find_elements_by_xpath('//div/div[1]/div[1]/div/div[2]/span')
    tag = driver.find_elements_by_xpath('//span[@class="i-b text ellipsis"]')
    for i in tag:
        Airline_name.append(i.text)
        
    l11 = len(Airline_name)
    length=l11
except:
    Airline_name.append('Nan')

#Airline_name
#len(Airline_name)


#departure time
try:
    tag = driver.find_elements_by_xpath('//div[@class="i-b pr"]')
    for i in tag:
        dep_time.append(i.text)
except:
    dep_time.append('Nan')


#arrival time
try:
    tag = driver.find_elements_by_xpath('//p[@class="bold fs-15 mb-2 pr time"]')
    for i in tag:
        arrival_time.append(i.text)
except:
    arrival_time.append('Nan')


#source
try:
    tag = driver.find_elements_by_xpath('//div[@class="i-b col-4 no-wrap text-right dtime col-3"]/p')
    for i in tag:
        source.append(i.text)
except:
    source.append('Nan')

#destination
try:
    tag = driver.find_elements_by_xpath('//div[@class="i-b pdd-0 text-left atime col-5"]//p[2]')
    for i in tag:
        destination.append(i.text)
except:
    destination.append('Nan') 

#total stops

try:
    tag = driver.find_elements_by_xpath('//div[@class=" font-lightgrey fs-10 tipsy i-b fs-10"]/span')
    for i in tag:
        total_stops.append(i.text)
except:
    total_stops.append('Nan')

#Price
try:
    tag = driver.find_elements_by_xpath('//div/div[1]/div[4]/div/div[1]/div/label/div/div[2]')
    for i in tag:
        price.append(i.text)
        
except:
    price.append('Nan')
    

#duration
try:
    tag = driver.find_elements_by_xpath('//p[@class="fs-12 bold du mb-2"]')
    for i in tag:
        duration.append(i.text)
        
except:
    duration.append('Nan')
    
len(Airline_name),len(arrival_time),len(dep_time),len(source),len(destination),len(duration),len(total_stops),len(price)
# Out:
# (2075, 2075, 2075, 2075, 2075, 2075, 2075, 2075)

# %%
df_Chennai_Kochi2 = pd.DataFrame({'Airline Name':Airline_name, 'Departure Date':'10 June 2022','Arrival Time':arrival_time,'Departure Time':dep_time, 'Source':source, 'Destination':destination,'Duration':duration,'Total Stops':total_stops,'Price':price})
df_Chennai_Kochi2
# Out:
#      Airline Name Departure Date Arrival Time Departure Time   Source  \
# 0       Air India   10 June 2022        19:10          15:25   Mumbai
# 1        Go First   10 June 2022        20:05          18:00   Mumbai
# 2        Go First   10 June 2022        02:20          00:10   Mumbai
# 3        Go First   10 June 2022        11:35          09:25   Mumbai
# 4        Go First   10 June 2022        13:10          11:00   Mumbai
# ...           ...            ...          ...            ...      ...
# 2070      Vistara   10 June 2022        19:10          07:00  Chennai
# 2071      Vistara   10 June 2022        19:10          07:00  Chennai
# 2072      Vistara   10 June 2022        19:10          07:00  Chennai
# 2073    Air India   10 June 2022        20:10          06:00  Chennai
# 2074    Air India   10 June 2022        20:10          09:55  Chennai
#
#      Destination Duration Total Stops   Price
# 0      New Delhi   3h 45m      1 Stop   7,308
# 1      New Delhi   2h 05m    Non Stop   8,042
# 2      New Delhi   2h 10m    Non Stop   8,042
# 3      New Delhi   2h 10m    Non Stop   8,042
# 4      New Delhi   2h 10m    Non Stop   8,042
# ...          ...      ...         ...     ...
# 2070       Kochi  12h 10m   2 Stop(s)  25,250
# 2071       Kochi  12h 10m   2 Stop(s)  25,250
# 2072       Kochi  12h 10m   2 Stop(s)  25,250
# 2073       Kochi  14h 10m      1 Stop  26,308
# 2074       Kochi  10h 15m      1 Stop  26,518
#
# [2075 rows x 9 columns]

# %%
driver.close()

# %%
df_Chennai_Kochi2.to_csv('flight_datas.csv')

# %% [markdown]
# # Kolkata - Delhi

# %%
#loading web driver
driver = webdriver.Chrome('chromedriver.exe')
driver.get('https://flight.yatra.com/air-search-ui/dom2/trigger?ADT=1&CHD=0&INF=0&class=Economy&destination=DEL&destinationCountry=IN&flexi=0&flight_depart_date=09%2F06%2F2022&hb=0&noOfSegments=1&origin=CCU&originCountry=IN&type=O&unique=1064340135954&version=1.1&viewName=normal')
driver.maximize_window()

# %%
last_height = driver.execute_script("return document.documentElement.scrollHeight")

# %%
while True:
    # Scroll down 'till "next load".
    driver.execute_script("window.scrollTo(0, document.documentElement.scrollHeight);")

    # Wait to load everything thus far.
    time.sleep(2)

    # Calculate new scroll height and compare with last scroll height.
    new_height = driver.execute_script("return document.documentElement.scrollHeight")
    if new_height == last_height:
        break
    last_height = new_height

    # One last scroll just in case.
driver.execute_script("window.scrollTo(0, document.documentElement.scrollHeight);")
sleep(2)

# %%
#airline tags
try:
    #tag = driver.find_elements_by_xpath('//div/div[1]/div[1]/div/div[2]/span')
    tag = driver.find_elements_by_xpath('//span[@class="i-b text ellipsis"]')
    for i in tag:
        Airline_name.append(i.text)
        
    l1 = len(Airline_name)
    length=l1
except:
    Airline_name.append('Nan')

#Airline_name
#len(Airline_name)


#departure time
try:
    tag = driver.find_elements_by_xpath('//div[@class="i-b pr"]')
    for i in tag:
        dep_time.append(i.text)
except:
    dep_time.append('Nan')


#arrival time
try:
    tag = driver.find_elements_by_xpath('//p[@class="bold fs-15 mb-2 pr time"]')
    for i in tag:
        arrival_time.append(i.text)
except:
    arrival_time.append('Nan')


#source
try:
    tag = driver.find_elements_by_xpath('//div[@class="i-b col-4 no-wrap text-right dtime col-3"]/p')
    for i in tag:
        source.append(i.text)
except:
    source.append('Nan')

#destination
try:
    tag = driver.find_elements_by_xpath('//div[@class="i-b pdd-0 text-left atime col-5"]//p[2]')
    for i in tag:
        destination.append(i.text)
except:
    destination.append('Nan') 

#total stops

try:
    tag = driver.find_elements_by_xpath('//div[@class=" font-lightgrey fs-10 tipsy i-b fs-10"]/span')
    for i in tag:
        total_stops.append(i.text)
except:
    total_stops.append('Nan')

#Price
try:
    tag = driver.find_elements_by_xpath('//div/div[1]/div[4]/div/div[1]/div/label/div/div[2]')
    for i in tag:
        price.append(i.text)
        
except:
    price.append('Nan')
    

#duration
try:
    tag = driver.find_elements_by_xpath('//p[@class="fs-12 bold du mb-2"]')
    for i in tag:
        duration.append(i.text)
        
except:
    duration.append('Nan')
    
len(Airline_name),len(arrival_time),len(dep_time),len(source),len(destination),len(duration),len(total_stops),len(price)
# Out:
# (2226, 2226, 2226, 2226, 2226, 2226, 2226, 2226)

# %%
df_Kolkata_Delhi = pd.DataFrame({'Airline Name':Airline_name, 'Departure Date':'9 June 2022','Arrival Time':arrival_time,'Departure Time':dep_time, 'Source':source, 'Destination':destination,'Duration':duration,'Total Stops':total_stops,'Price':price})
df_Kolkata_Delhi

# %%
driver.close()

# %%
df_Kolkata_Delhi.to_csv('flight_datas.csv')

# %% [markdown]
# # Ahmedabad - Mumbai

# %%
#loading web driver
#10 June
driver = webdriver.Chrome('chromedriver.exe')
driver.get('https://flight.yatra.com/air-search-ui/dom2/trigger?type=O&viewName=normal&flexi=0&noOfSegments=1&origin=AMD&originCountry=IN&destination=BOM&destinationCountry=IN&flight_depart_date=10%2F06%2F2022&ADT=1&CHD=0&INF=0&class=Economy&source=fresco-home&unqvaldesktop=1206341387608')
driver.maximize_window()

# %%
last_height = driver.execute_script("return document.documentElement.scrollHeight")

# %%
while True:
    # Scroll down 'till "next load".
    driver.execute_script("window.scrollTo(0, document.documentElement.scrollHeight);")

    # Wait to load everything thus far.
    time.sleep(2)

    # Calculate new scroll height and compare with last scroll height.
    new_height = driver.execute_script("return document.documentElement.scrollHeight")
    if new_height == last_height:
        break
    last_height = new_height

    # One last scroll just in case.
driver.execute_script("window.scrollTo(0, document.documentElement.scrollHeight);")
sleep(2)

# %%
#airline tags
try:
    #tag = driver.find_elements_by_xpath('//div/div[1]/div[1]/div/div[2]/span')
    tag = driver.find_elements_by_xpath('//span[@class="i-b text ellipsis"]')
    for i in tag:
        Airline_name.append(i.text)
        
    l1 = len(Airline_name)
    length=l1
except:
    Airline_name.append('Nan')

#Airline_name
#len(Airline_name)


#departure time
try:
    tag = driver.find_elements_by_xpath('//div[@class="i-b pr"]')
    for i in tag:
        dep_time.append(i.text)
except:
    dep_time.append('Nan')


#arrival time
try:
    tag = driver.find_elements_by_xpath('//p[@class="bold fs-15 mb-2 pr time"]')
    for i in tag:
        arrival_time.append(i.text)
except:
    arrival_time.append('Nan')


#source
try:
    tag = driver.find_elements_by_xpath('//div[@class="i-b col-4 no-wrap text-right dtime col-3"]/p')
    for i in tag:
        source.append(i.text)
except:
    source.append('Nan')

#destination
try:
    tag = driver.find_elements_by_xpath('//div[@class="i-b pdd-0 text-left atime col-5"]//p[2]')
    for i in tag:
        destination.append(i.text)
except:
    destination.append('Nan') 

#total stops

try:
    tag = driver.find_elements_by_xpath('//div[@class=" font-lightgrey fs-10 tipsy i-b fs-10"]/span')
    for i in tag:
        total_stops.append(i.text)
except:
    total_stops.append('Nan')

#Price
try:
    tag = driver.find_elements_by_xpath('//div/div[1]/div[4]/div/div[1]/div/label/div/div[2]')
    for i in tag:
        price.append(i.text)
        
except:
    price.append('Nan')
    

#duration
try:
    tag = driver.find_elements_by_xpath('//p[@class="fs-12 bold du mb-2"]')
    for i in tag:
        duration.append(i.text)
        
except:
    duration.append('Nan')
    
len(Airline_name),len(arrival_time),len(dep_time),len(source),len(destination),len(duration),len(total_stops),len(price)
# Out:
# (89, 89, 89, 89, 89, 89, 89, 89)

# %%
df_Ahm_Mum = pd.DataFrame({'Airline Name':Airline_name, 'Departure Date':'10 June 2022','Arrival Time':arrival_time,'Departure Time':dep_time, 'Source':source, 'Destination':destination,'Duration':duration,'Total Stops':total_stops,'Price':price})
df_Ahm_Mum
# Out:
#    Airline Name Departure Date    Arrival Time Departure Time     Source  \
# 0       Vistara   10 June 2022           06:15          05:05  Ahmedabad
# 1        IndiGo   10 June 2022  00:20\n+ 1 day          23:25  Ahmedabad
# 2        IndiGo   10 June 2022           05:30          04:25  Ahmedabad
# 3      Go First   10 June 2022           10:20          09:05  Ahmedabad
# 4      Go First   10 June 2022           15:00          13:45  Ahmedabad
# ..          ...            ...             ...            ...        ...
# 84      Vistara   10 June 2022           22:20          08:30  Ahmedabad
# 85      Vistara   10 June 2022           22:20          06:45  Ahmedabad
# 86     Go First   10 June 2022           14:20          05:45  Ahmedabad
# 87      Vistara   10 June 2022           20:15          08:30  Ahmedabad
# 88      Vistara   10 June 2022           19:00          08:30  Ahmedabad
#
#    Destination Duration Total Stops   Price
# 0       Mumbai   1h 10m    Non Stop   4,863
# 1       Mumbai   0h 55m    Non Stop   5,586
# 2       Mumbai   1h 05m    Non Stop   5,586
# 3       Mumbai   1h 15m    Non Stop   5,586
# 4       Mumbai   1h 15m    Non Stop   5,586
# ..         ...      ...         ...     ...
# 84      Mumbai  13h 50m   2 Stop(s)  20,426
# 85      Mumbai  15h 35m   2 Stop(s)  21,014
# 86      Mumbai   8h 35m      1 Stop  21,634
# 87      Mumbai  11h 45m   2 Stop(s)  26,062
# 88      Mumbai  10h 30m   2 Stop(s)  28,215
#
# [89 rows x 9 columns]

# %%
driver.close()

# %% [markdown]
# # Hyderabad - Chennai

# %%
#loading web driver
#10 June
driver = webdriver.Chrome('chromedriver.exe')
driver.get('https://flight.yatra.com/air-search-ui/dom2/trigger?ADT=1&CHD=0&INF=0&class=Economy&destination=MAA&destinationCountry=IN&flexi=0&flight_depart_date=10%2F06%2F2022&hb=0&noOfSegments=1&origin=HYD&originCountry=IN&type=O&unique=453409932967&version=1.1&viewName=normal')
driver.maximize_window()

# %%
last_height = driver.execute_script("return document.documentElement.scrollHeight")

# %%
while True:
    # Scroll down 'till "next load".
    driver.execute_script("window.scrollTo(0, document.documentElement.scrollHeight);")

    # Wait to load everything thus far.
    time.sleep(2)

    # Calculate new scroll height and compare with last scroll height.
    new_height = driver.execute_script("return document.documentElement.scrollHeight")
    if new_height == last_height:
        break
    last_height = new_height

    # One last scroll just in case.
driver.execute_script("window.scrollTo(0, document.documentElement.scrollHeight);")
sleep(2)

# %%
#airline tags
try:
    #tag = driver.find_elements_by_xpath('//div/div[1]/div[1]/div/div[2]/span')
    tag = driver.find_elements_by_xpath('//span[@class="i-b text ellipsis"]')
    for i in tag:
        Airline_name.append(i.text)
        
    l1 = len(Airline_name)
    length=l1
except:
    Airline_name.append('Nan')

#Airline_name
#len(Airline_name)


#departure time
try:
    tag = driver.find_elements_by_xpath('//div[@class="i-b pr"]')
    for i in tag:
        dep_time.append(i.text)
except:
    dep_time.append('Nan')


#arrival time
try:
    tag = driver.find_elements_by_xpath('//p[@class="bold fs-15 mb-2 pr time"]')
    for i in tag:
        arrival_time.append(i.text)
except:
    arrival_time.append('Nan')


#source
try:
    tag = driver.find_elements_by_xpath('//div[@class="i-b col-4 no-wrap text-right dtime col-3"]/p')
    for i in tag:
        source.append(i.text)
except:
    source.append('Nan')

#destination
try:
    tag = driver.find_elements_by_xpath('//div[@class="i-b pdd-0 text-left atime col-5"]//p[2]')
    for i in tag:
        destination.append(i.text)
except:
    destination.append('Nan') 

#total stops

try:
    tag = driver.find_elements_by_xpath('//div[@class=" font-lightgrey fs-10 tipsy i-b fs-10"]/span')
    for i in tag:
        total_stops.append(i.text)
except:
    total_stops.append('Nan')

#Price
try:
    tag = driver.find_elements_by_xpath('//div/div[1]/div[4]/div/div[1]/div/label/div/div[2]')
    for i in tag:
        price.append(i.text)
        
except:
    price.append('Nan')
    

#duration
try:
    tag = driver.find_elements_by_xpath('//p[@class="fs-12 bold du mb-2"]')
    for i in tag:
        duration.append(i.text)
        
except:
    duration.append('Nan')
    
len(Airline_name),len(arrival_time),len(dep_time),len(source),len(destination),len(duration),len(total_stops),len(price)
# Out:
# (187, 187, 187, 187, 187, 187, 187, 187)

# %%
df_Hyderabad_Chennai = pd.DataFrame({'Airline Name':Airline_name, 'Departure Date':'10 June 2022','Arrival Time':arrival_time,'Departure Time':dep_time, 'Source':source, 'Destination':destination,'Duration':duration,'Total Stops':total_stops,'Price':price})
df_Hyderabad_Chennai
# Out:
#     Airline Name Departure Date    Arrival Time Departure Time     Source  \
# 0        Vistara   10 June 2022           06:15          05:05  Ahmedabad
# 1         IndiGo   10 June 2022  00:20\n+ 1 day          23:25  Ahmedabad
# 2         IndiGo   10 June 2022           05:30          04:25  Ahmedabad
# 3       Go First   10 June 2022           10:20          09:05  Ahmedabad
# 4       Go First   10 June 2022           15:00          13:45  Ahmedabad
# ..           ...            ...             ...            ...        ...
# 182      Vistara   10 June 2022           19:50          10:10  Hyderabad
# 183      Vistara   10 June 2022           20:15          11:35  Hyderabad
# 184      Vistara   10 June 2022           23:05          13:25  Hyderabad
# 185      Vistara   10 June 2022           23:05          13:25  Hyderabad
# 186    Air India   10 June 2022  07:25\n+ 1 day          16:10  Hyderabad
#
#     Destination Duration Total Stops   Price
# 0        Mumbai   1h 10m    Non Stop   4,863
# 1        Mumbai   0h 55m    Non Stop   5,586
# 2        Mumbai   1h 05m    Non Stop   5,586
# 3        Mumbai   1h 15m    Non Stop   5,586
# 4        Mumbai   1h 15m    Non Stop   5,586
# ..          ...      ...         ...     ...
# 182     Chennai   9h 40m   2 Stop(s)  23,832
# 183     Chennai   8h 40m   2 Stop(s)  25,793
# 184     Chennai   9h 40m   2 Stop(s)  26,948
# 185     Chennai   9h 40m   2 Stop(s)  27,998
# 186     Chennai  15h 15m   2 Stop(s)  28,313
#
# [187 rows x 9 columns]

# %%
driver.close()

# %% [markdown]
# # Kochi - Chennai

# %%
#loading web driver
#10 June
driver = webdriver.Chrome('chromedriver.exe')
driver.get('https://flight.yatra.com/air-search-ui/dom2/trigger?ADT=1&CHD=0&INF=0&class=Economy&destination=MAA&destinationCountry=IN&flexi=0&flight_depart_date=10%2F06%2F2022&hb=0&noOfSegments=1&origin=COK&originCountry=IN&type=O&unique=1076625178551&version=1.1&viewName=normal')
driver.maximize_window()

# %%
last_height = driver.execute_script("return document.documentElement.scrollHeight")

# %%
while True:
    # Scroll down 'till "next load".
    driver.execute_script("window.scrollTo(0, document.documentElement.scrollHeight);")

    # Wait to load everything thus far.
    time.sleep(2)

    # Calculate new scroll height and compare with last scroll height.
    new_height = driver.execute_script("return document.documentElement.scrollHeight")
    if new_height == last_height:
        break
    last_height = new_height

    # One last scroll just in case.
driver.execute_script("window.scrollTo(0, document.documentElement.scrollHeight);")
sleep(2)

# %%
#airline tags
try:
    #tag = driver.find_elements_by_xpath('//div/div[1]/div[1]/div/div[2]/span')
    tag = driver.find_elements_by_xpath('//span[@class="i-b text ellipsis"]')
    for i in tag:
        Airline_name.append(i.text)
        
    l1 = len(Airline_name)
    length=l1
except:
    Airline_name.append('Nan')

#Airline_name
#len(Airline_name)


#departure time
try:
    tag = driver.find_elements_by_xpath('//div[@class="i-b pr"]')
    for i in tag:
        dep_time.append(i.text)
except:
    dep_time.append('Nan')


#arrival time
try:
    tag = driver.find_elements_by_xpath('//p[@class="bold fs-15 mb-2 pr time"]')
    for i in tag:
        arrival_time.append(i.text)
except:
    arrival_time.append('Nan')


#source
try:
    tag = driver.find_elements_by_xpath('//div[@class="i-b col-4 no-wrap text-right dtime col-3"]/p')
    for i in tag:
        source.append(i.text)
except:
    source.append('Nan')

#destination
try:
    tag = driver.find_elements_by_xpath('//div[@class="i-b pdd-0 text-left atime col-5"]//p[2]')
    for i in tag:
        destination.append(i.text)
except:
    destination.append('Nan') 

#total stops

try:
    tag = driver.find_elements_by_xpath('//div[@class=" font-lightgrey fs-10 tipsy i-b fs-10"]/span')
    for i in tag:
        total_stops.append(i.text)
except:
    total_stops.append('Nan')

#Price
try:
    tag = driver.find_elements_by_xpath('//div/div[1]/div[4]/div/div[1]/div/label/div/div[2]')
    for i in tag:
        price.append(i.text)
        
except:
    price.append('Nan')
    

#duration
try:
    tag = driver.find_elements_by_xpath('//p[@class="fs-12 bold du mb-2"]')
    for i in tag:
        duration.append(i.text)
        
except:
    duration.append('Nan')
    
len(Airline_name),len(arrival_time),len(dep_time),len(source),len(destination),len(duration),len(total_stops),len(price)
# Out:
# (241, 241, 241, 241, 241, 241, 241, 241)

# %%
df_Kochi_Chennai = pd.DataFrame({'Airline Name':Airline_name, 'Departure Date':'10 June 2022','Arrival Time':arrival_time,'Departure Time':dep_time, 'Source':source, 'Destination':destination,'Duration':duration,'Total Stops':total_stops,'Price':price})
df_Kochi_Chennai
# Out:
#     Airline Name Departure Date    Arrival Time Departure Time     Source  \
# 0        Vistara   10 June 2022           06:15          05:05  Ahmedabad
# 1         IndiGo   10 June 2022  00:20\n+ 1 day          23:25  Ahmedabad
# 2         IndiGo   10 June 2022           05:30          04:25  Ahmedabad
# 3       Go First   10 June 2022           10:20          09:05  Ahmedabad
# 4       Go First   10 June 2022           15:00          13:45  Ahmedabad
# ..           ...            ...             ...            ...        ...
# 236    Air India   10 June 2022  19:15\n+ 1 day          20:30      Kochi
# 237      Vistara   10 June 2022           23:05          09:15      Kochi
# 238      Vistara   10 June 2022           23:05          09:15      Kochi
# 239      Vistara   10 June 2022           19:50          09:15      Kochi
# 240      Vistara   10 June 2022           23:05          09:15      Kochi
#
#     Destination Duration Total Stops   Price
# 0        Mumbai   1h 10m    Non Stop   4,863
# 1        Mumbai   0h 55m    Non Stop   5,586
# 2        Mumbai   1h 05m    Non Stop   5,586
# 3        Mumbai   1h 15m    Non Stop   5,586
# 4        Mumbai   1h 15m    Non Stop   5,586
# ..          ...      ...         ...     ...
# 236     Chennai  22h 45m   2 Stop(s)  23,227
# 237     Chennai  13h 50m   2 Stop(s)  24,045
# 238     Chennai  13h 50m   2 Stop(s)  24,045
# 239     Chennai  10h 35m   2 Stop(s)  25,746
# 240     Chennai  13h 50m   2 Stop(s)  28,169
#
# [241 rows x 9 columns]

# %%
driver.close()

# %% [markdown]
# # Patna - Lucknow

# %%
#loading web driver
driver = webdriver.Chrome('chromedriver.exe')
driver.get('https://flight.yatra.com/air-search-ui/dom2/trigger?ADT=1&CHD=0&INF=0&class=Economy&destination=LKO&destinationCountry=IN&flexi=0&flight_depart_date=10%2F06%2F2022&hb=0&noOfSegments=1&origin=PAT&originCountry=IN&type=O&unique=1160596078303&version=1.1&viewName=normal')
driver.maximize_window()

# %%
last_height = driver.execute_script("return document.documentElement.scrollHeight")

# %%
while True:
    # Scroll down 'till "next load".
    driver.execute_script("window.scrollTo(0, document.documentElement.scrollHeight);")

    # Wait to load everything thus far.
    time.sleep(2)

    # Calculate new scroll height and compare with last scroll height.
    new_height = driver.execute_script("return document.documentElement.scrollHeight")
    if new_height == last_height:
        break
    last_height = new_height

    # One last scroll just in case.
driver.execute_script("window.scrollTo(0, document.documentElement.scrollHeight);")
sleep(2)

# %%
#airline tags
try:
    #tag = driver.find_elements_by_xpath('//div/div[1]/div[1]/div/div[2]/span')
    tag = driver.find_elements_by_xpath('//span[@class="i-b text ellipsis"]')
    for i in tag:
        Airline_name.append(i.text)
        
    l1 = len(Airline_name)
    length=l1
except:
    Airline_name.append('Nan')

#Airline_name
#len(Airline_name)


#departure time
try:
    tag = driver.find_elements_by_xpath('//div[@class="i-b pr"]')
    for i in tag:
        dep_time.append(i.text)
except:
    dep_time.append('Nan')


#arrival time
try:
    tag = driver.find_elements_by_xpath('//p[@class="bold fs-15 mb-2 pr time"]')
    for i in tag:
        arrival_time.append(i.text)
except:
    arrival_time.append('Nan')


#source
try:
    tag = driver.find_elements_by_xpath('//div[@class="i-b col-4 no-wrap text-right dtime col-3"]/p')
    for i in tag:
        source.append(i.text)
except:
    source.append('Nan')

#destination
try:
    tag = driver.find_elements_by_xpath('//div[@class="i-b pdd-0 text-left atime col-5"]//p[2]')
    for i in tag:
        destination.append(i.text)
except:
    destination.append('Nan') 

#total stops

try:
    tag = driver.find_elements_by_xpath('//div[@class=" font-lightgrey fs-10 tipsy i-b fs-10"]/span')
    for i in tag:
        total_stops.append(i.text)
except:
    total_stops.append('Nan')

#Price
try:
    tag = driver.find_elements_by_xpath('//div/div[1]/div[4]/div/div[1]/div/label/div/div[2]')
    for i in tag:
        price.append(i.text)
        
except:
    price.append('Nan')
    

#duration
try:
    tag = driver.find_elements_by_xpath('//p[@class="fs-12 bold du mb-2"]')
    for i in tag:
        duration.append(i.text)
        
except:
    duration.append('Nan')
    
len(Airline_name),len(arrival_time),len(dep_time),len(source),len(destination),len(duration),len(total_stops),len(price)
# Out:
# (264, 264, 264, 264, 264, 264, 264, 264)

# %%
df_Patna_Lucknow = pd.DataFrame({'Airline Name':Airline_name, 'Departure Date':'10 June 2022','Arrival Time':arrival_time,'Departure Time':dep_time, 'Source':source, 'Destination':destination,'Duration':duration,'Total Stops':total_stops,'Price':price})
df_Patna_Lucknow
# Out:
#     Airline Name Departure Date    Arrival Time Departure Time     Source  \
# 0        Vistara   10 June 2022           06:15          05:05  Ahmedabad
# 1         IndiGo   10 June 2022  00:20\n+ 1 day          23:25  Ahmedabad
# 2         IndiGo   10 June 2022           05:30          04:25  Ahmedabad
# 3       Go First   10 June 2022           10:20          09:05  Ahmedabad
# 4       Go First   10 June 2022           15:00          13:45  Ahmedabad
# ..           ...            ...             ...            ...        ...
# 259    Air India   10 June 2022  13:25\n+ 1 day          09:15      Patna
# 260    Air India   10 June 2022  13:20\n+ 1 day          19:10      Patna
# 261    Air India   10 June 2022  13:20\n+ 1 day          19:10      Patna
# 262    Air India   10 June 2022  13:20\n+ 1 day          16:00      Patna
# 263    Air India   10 June 2022  13:20\n+ 1 day          16:00      Patna
#
#     Destination Duration Total Stops   Price
# 0        Mumbai   1h 10m    Non Stop   4,863
# 1        Mumbai   0h 55m    Non Stop   5,586
# 2        Mumbai   1h 05m    Non Stop   5,586
# 3        Mumbai   1h 15m    Non Stop   5,586
# 4        Mumbai   1h 15m    Non Stop   5,586
# ..          ...      ...         ...     ...
# 259     Lucknow  28h 10m   3 Stop(s)  17,963
# 260     Lucknow  18h 10m   2 Stop(s)  22,842
# 261     Lucknow  18h 10m   2 Stop(s)  22,842
# 262     Lucknow  21h 20m   2 Stop(s)  23,577
# 263     Lucknow  21h 20m   2 Stop(s)  23,577
#
# [264 rows x 9 columns]

# %%
df = pd.read_csv('flight_datas.csv')
df
# Out:
#       Unnamed: 0 Airline Name Departure Date    Arrival Time Departure Time  \
# 0              0    Air India    9 June 2022           19:10          15:25
# 1              1     Go First    9 June 2022           20:05          18:00
# 2              2     Go First    9 June 2022           02:20          00:10
# 3              3     Go First    9 June 2022           11:35          09:25
# 4              4     Go First    9 June 2022           13:10          11:00
# ...          ...          ...            ...             ...            ...
# 2221        2221      Vistara    9 June 2022  13:25\n+ 1 day          20:35
# 2222        2222      Vistara    9 June 2022  13:25\n+ 1 day          17:35
# 2223        2223      Vistara    9 June 2022  13:25\n+ 1 day          17:35
# 2224        2224      Vistara    9 June 2022  09:55\n+ 1 day          10:25
# 2225        2225      Vistara    9 June 2022  09:55\n+ 1 day          10:25
#
#        Source Destination Duration Total Stops   Price
# 0      Mumbai   New Delhi   3h 45m      1 Stop   7,308
# 1      Mumbai   New Delhi   2h 05m    Non Stop   8,042
# 2      Mumbai   New Delhi   2h 10m    Non Stop   8,042
# 3      Mumbai   New Delhi   2h 10m    Non Stop   8,042
# 4      Mumbai   New Delhi   2h 10m    Non Stop   8,042
# ...       ...         ...      ...         ...     ...
# 2221  Kolkata   New Delhi  16h 50m   2 Stop(s)  23,614
# 2222  Kolkata   New Delhi  19h 50m   2 Stop(s)  23,614
# 2223  Kolkata   New Delhi  19h 50m   2 Stop(s)  23,614
# 2224  Kolkata   New Delhi  23h 30m   2 Stop(s)  23,614
# 2225  Kolkata   New Delhi  23h 30m   2 Stop(s)  23,614
#
# [2226 rows x 10 columns]

# %%
df.drop(columns='Unnamed: 0', inplace=True)

# %%
df.head(5)
# Out:
#   Airline Name Departure Date Arrival Time Departure Time  Source Destination  \
# 0    Air India    9 June 2022        19:10          15:25  Mumbai   New Delhi
# 1     Go First    9 June 2022        20:05          18:00  Mumbai   New Delhi
# 2     Go First    9 June 2022        02:20          00:10  Mumbai   New Delhi
# 3     Go First    9 June 2022        11:35          09:25  Mumbai   New Delhi
# 4     Go First    9 June 2022        13:10          11:00  Mumbai   New Delhi
#
#   Duration Total Stops  Price
# 0   3h 45m      1 Stop  7,308
# 1   2h 05m    Non Stop  8,042
# 2   2h 10m    Non Stop  8,042
# 3   2h 10m    Non Stop  8,042
# 4   2h 10m    Non Stop  8,042

# %%
df_Patna_Lucknow.head(2)
# Out:
#   Airline Name Departure Date    Arrival Time Departure Time     Source  \
# 0      Vistara   10 June 2022           06:15          05:05  Ahmedabad
# 1       IndiGo   10 June 2022  00:20\n+ 1 day          23:25  Ahmedabad
#
#   Destination Duration Total Stops  Price
# 0      Mumbai   1h 10m    Non Stop  4,863
# 1      Mumbai   0h 55m    Non Stop  5,586

# %%
import pandas as pd
df_flightData=pd.concat((df,df_Patna_Lucknow), ignore_index=True)
df_flightData
# Out:
#      Airline Name Departure Date    Arrival Time Departure Time  Source  \
# 0       Air India    9 June 2022           19:10          15:25  Mumbai
# 1        Go First    9 June 2022           20:05          18:00  Mumbai
# 2        Go First    9 June 2022           02:20          00:10  Mumbai
# 3        Go First    9 June 2022           11:35          09:25  Mumbai
# 4        Go First    9 June 2022           13:10          11:00  Mumbai
# ...           ...            ...             ...            ...     ...
# 2485    Air India   10 June 2022  13:25\n+ 1 day          09:15   Patna
# 2486    Air India   10 June 2022  13:20\n+ 1 day          19:10   Patna
# 2487    Air India   10 June 2022  13:20\n+ 1 day          19:10   Patna
# 2488    Air India   10 June 2022  13:20\n+ 1 day          16:00   Patna
# 2489    Air India   10 June 2022  13:20\n+ 1 day          16:00   Patna
#
#      Destination Duration Total Stops   Price
# 0      New Delhi   3h 45m      1 Stop   7,308
# 1      New Delhi   2h 05m    Non Stop   8,042
# 2      New Delhi   2h 10m    Non Stop   8,042
# 3      New Delhi   2h 10m    Non Stop   8,042
# 4      New Delhi   2h 10m    Non Stop   8,042
# ...          ...      ...         ...     ...
# 2485     Lucknow  28h 10m   3 Stop(s)  17,963
# 2486     Lucknow  18h 10m   2 Stop(s)  22,842
# 2487     Lucknow  18h 10m   2 Stop(s)  22,842
# 2488     Lucknow  21h 20m   2 Stop(s)  23,577
# 2489     Lucknow  21h 20m   2 Stop(s)  23,577
#
# [2490 rows x 9 columns]

# %%
df_flightData.to_csv('flight_datas.csv')
