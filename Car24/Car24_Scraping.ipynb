# %%
# Importing Libraries
import selenium
import pandas as pd
from selenium import webdriver
import time

import warnings
warnings.filterwarnings("ignore")
# Importing required Exceptions 
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException

# %%
def car24(a,b):
    driver = webdriver.Chrome('chromedriver.exe')
    #Extract car from Mumbai region
    driver.get('https://www.cars24.com/buy-used-car?sort=P&storeCityId='+str(a)+'&pinId='+str(b)+'')
    driver.maximize_window()
    time.sleep(2)
    # 500 time we scroll down by 10000 in order to generate more images on the website
    for _ in range(500):
        driver.execute_script("window.scrollBy(0,10000)")   
    
    #Make empty lists  
    car_Brand=[]
    car_owner=[]
    car_kilometers=[]
    car_fuel_type=[]
    car_registration=[]
    car_price=[]
    car_model=[]
    car_transmission=[]
    # Extracting Brand from xpath
    try:
        for i in driver.find_elements_by_xpath("//h2[@class='_3FpCg']"):
            car_Brand.append(i.text)
    except NoSuchElementException:
        car_Brand.append("_")

    # Extracting Name from xpath
    try:
        for i in driver.find_elements_by_xpath("//div[@class='_1l4fi']/ul/li[2]"):
            car_owner.append(i.text)
    except NoSuchElementException:
        car_owner.append('-')

    # Extracting colour from xpath
    try:
        for i in driver.find_elements_by_xpath("//div[@class='_1l4fi']/ul/li[1]"):
            car_kilometers.append(i.text)
    except NoSuchElementException:
        car_kilometers.append('-')


    # Extracting colour from xpath
    try:
        for i in driver.find_elements_by_xpath("//p[@class='cvakB']/span"):
            car_transmission.append(i.text)
    except NoSuchElementException:
        car_transmission.append('-')

    # Extracting Name from xpath
    try:
        for i in driver.find_elements_by_xpath("//div[@class='_1l4fi']/ul/li[3]"):
            car_fuel_type.append(i.text)
    except NoSuchElementException:
        car_fuel_type.append('-')

    # Extracting Name from xpath
    try:
        for i in driver.find_elements_by_xpath("//p[@class='cvakB']"):
            car_model.append(i.text)
    except NoSuchElementException:
        car_model.append('-')        

    # Extracting colour from xpath
    try:
        for i in driver.find_elements_by_xpath("//div[@class='_19zc5']/div[2]"):
            car_price.append(i.text)
    except NoSuchElementException:
        car_price.append('-')

    car=pd.DataFrame({})
    car["car_Brand"]=car_Brand
    car["car_owner"]=car_owner
    car["car_kilometers"]=car_kilometers
    car["car_fuel_type"]=car_fuel_type
    car["car_transmission"]=car_transmission
    car["car_model"]=car_model
    car["car_price"]=car_price
    return(car)

# %%
mumbai=  car24(2378,400001)
mumbai
# Out:
#                   car_Brand  car_owner car_kilometers car_fuel_type  \
# 0          2014 Honda Amaze  1st Owner      53,242 km        Petrol
# 1         2019 Maruti Dzire  1st Owner      31,248 km        Petrol
# 2        2017 Ford Ecosport  1st Owner         471 km        Petrol
# 3           2019 KIA SELTOS  1st Owner      12,407 km        Petrol
# 4    2017 Hyundai Elite i20  1st Owner      35,164 km        Petrol
# ..                      ...        ...            ...           ...
# 689          2021 MG HECTOR  1st Owner       8,077 km        Petrol
# 690        2021 Maruti Alto  1st Owner       9,706 km        Petrol
# 691    2021 Maruti S PRESSO  1st Owner         697 km        Petrol
# 692         2016 Honda Brio  1st Owner      59,581 km        Petrol
# 693         2017 Honda Jazz  1st Owner      57,606 km        Petrol
# %%
surat=car24(1605,394101)
surat['location']='Surat'
surat
# Out:
#                     car_Brand  car_owner car_kilometers car_fuel_type  \
# 0     2018 Maruti Wagon R 1.0  1st Owner      13,673 km        Petrol
# 1      2015 Hyundai Elite i20  1st Owner      79,922 km        Petrol
# 2          2017 Maruti Ertiga  1st Owner      48,443 km        Diesel
# 3             2018 Honda City  1st Owner      28,435 km        Petrol
# 4           2018 Renault Kwid  1st Owner      71,569 km        Petrol
# 5                2017 Audi Q3  1st Owner      67,715 km        Petrol
# 6           2021 Tata Harrier  1st Owner      12,503 km        Diesel
# 7           2017 Maruti Dzire  1st Owner      60,688 km        Diesel
# 8            2018 Maruti Ciaz  1st Owner      38,249 km        Petrol
# 9        2021 Hyundai NEW I20  1st Owner       1,540 km        Petrol
# 10       2020 HYUNDAI NEW I20  1st Owner      18,909 km        Petrol
# 11          2020 Maruti Dzire  1st Owner      12,444 km        Petrol
# ...

# %%
kochi=car24(6351,682001)
kochi['location']='Kochi'
kochi
# Out:
#                    car_Brand  car_owner car_kilometers car_fuel_type  \
# 0      2017 Mahindra Scorpio  1st Owner      58,972 km        Diesel
# 1        2015 Maruti Celerio  2nd Owner      42,242 km        Petrol
# 2         2011 Hyundai Verna  1st Owner      78,395 km        Petrol
# 3      2013 Volkswagen Vento  1st Owner    1,44,383 km        Diesel
# 4       2016 Volkswagen Ameo  1st Owner      64,357 km        Diesel
# ..                       ...        ...            ...           ...
# 390   2014 Hyundai Grand i10  1st Owner      51,884 km        Petrol
# 391   2019 Hyundai Grand i10  1st Owner      10,725 km        Petrol
# 392   2016 Hyundai Grand i10  1st Owner      16,855 km        Petrol
# 393   2016 Hyundai Grand i10  1st Owner      51,324 km        Petrol
# 394  2018 Hyundai NEW SANTRO  2nd Owner      27,980 km        Petrol
#
#     car_transmission                       car_model   car_price location
# ...

# %%
lucknow=car24(290,226001)
lucknow['location']='Lucknow'
lucknow
# Out:
#                     car_Brand  car_owner car_kilometers car_fuel_type  \
# 0          2019 Maruti Baleno  1st Owner      18,829 km        Petrol
# 1          2020 Hyundai Creta  1st Owner       5,854 km        Petrol
# 2         2019 Datsun Redi Go  1st Owner      34,810 km        Petrol
# 3          2017 Ford Ecosport  2nd Owner      29,595 km        Petrol
# 4              2021 KIA SONET  1st Owner      13,887 km        Diesel
# ..                        ...        ...            ...           ...
# 89       2014 Maruti Alto 800  1st Owner      27,734 km        Petrol
# 90  2018 Maruti Vitara Brezza  1st Owner      29,031 km        Diesel
# 91       2019 Maruti S PRESSO  2nd Owner       5,289 km        Petrol
# 92         2020 Maruti Baleno  1st Owner      23,928 km        Petrol
# 93     2018 Hyundai Grand i10  1st Owner      35,373 km        Petrol
#
#    car_transmission                     car_model   car_price location
# ...

# %%
#Combine all three DataFrames
cars24_data=pd.concat([mumbai,gurgaon, pune, banglore,chennai,ahmedabad, noida, 
                       kolkata, hyderabad,chandigarh,bhopal,delhi,coimbatore,surat,kochi,lucknow]).reset_index()
cars24_data.to_csv('Car24_data.csv')
